# %% [markdown]
# ## Whistler Blackcomb resort status
#
# This will be used as an example of how to grab real-time data from https://whistlerblackcomb.com and display it here.

# %%
#imports needed for scrapping web pages
import requests, bs4

# %%
#get the website page

#this page has the mountain conditions for whistler blackcomb
res = requests.get("https://www.whistlerblackcomb.com/the-mountain/mountain-conditions/snow-and-weather-report.aspx")

# %%
#use Beautiful Soup to convert this into a soup
soup = bs4.BeautifulSoup(res.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head><script src="/tof9sf97v.js?matcher" type="text/javascript"></script><script src="/tof9sf97v.js?single" type="text/javascript"></script>
# <!-- Bidtellect Universal Pixel -->
# <script data-dtconfig="rid=RID_-312796552|rpid=969218742|domain=whistlerblackcomb.com|reportUrl=/rb_bf89404baq|app=0d20c77a5fc281dd|cuc=cohvrpsd|ssc=1|mel=100000|featureHash=ICANVfhqru|dpvc=1|md=mdcc1=a#mainNavInner ^rb div.main_nav__utility ^rb ul ^rb li.main_nav__utility_item.hidden-md.hidden-sm.hidden-xs ^rb a ^rb div.main_nav__utility_item_label,mdcc2=bs.pageName,mdcc3=bs.pageURL,mdcc4=bs.pageType,mdcc5=bs.purchaseID,mdcc6=bs.transactionID,mdcc7=bs.visitorID|lastModification=1728386363984|tp=500,50,0|rdnt=1|uxrgce=1|agentUri=/ruxitagentjs_ICANVfhqru_10299241001084140.js" src="/ruxitagentjs_ICANVfhqru_10299241001084140.js" type="text/javascript"></script><script async="" src="https://cdn.bttrack.com/universal/45273"></script>
# <!-- OneTrust Cookies Consent Notice start -->
# <script charset="UTF-8" data-domain-script="b7de5815-ebc4-4b13-96e1-f75f6359ea1d" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
#             function OptanonWrapper() { }
#         </script>
# <!-- OneTrust Cookies Consent Notice end -->
# <!-- BEGIN HEAD Delivery -->
# <title>Snow and Weather Report | Whistler Blackcomb</title>
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="date=no" name="format-detection"/>
# <meta content="address=no" name="format-detection"/>
# <link href="https://www.whistlerblackcomb.com/the-mountain/mountain-conditions/snow-and-weather-report.aspx" rel="canonical"/>
# <link href="/Assets/images/sites/whistlerblackcomb/favicon.ico" rel="icon"/>
# <meta content="index,follow" name="robots"/>
# <meta content="Get up-to-the-minute snow and weather reports for Whistler Blackcomb, including mountain temperatures, wind speeds, snowfall accumulation, and more." name="description"/><meta content="Get up-to-the-minute snow and weather reports for Whistler Blackcomb, including mountain temperatures, wind speeds, snowfall accumulation, and more." property="og:description"/><link href="https://scene7.vailresorts.com/is/image/vailresorts/20230316_WB_Berger_008:Flip-in-Card" rel="image_src"/>
# <meta content="https://scene7.vailresorts.com/is/image/vailresorts/20230316_WB_Berger_008:Flip-in-Card" property="og:image"/><meta content="https://www.whistlerblackcomb.com/the-mountain/mountain-conditions/snow-and-weather-report.aspx" property="og:url"/><meta content="Snow and Weather Report | Whistler Blackcomb" property="og:title"/> <!-- This has to load before the bundles call -->
# <script type="text/javascript">window.digitalData = {"pageInstanceID":null,"page":{"category":{"pageType":null,"primaryCategory":null,"subCategories":[]},"pageInfo":{"pageID":null,"pageName":"whistler blackcomb:the mountain:mountain conditions:Snow and Weather Report","destinationURL":"https://www.whistlerblackcomb.com/the-mountain/mountain-conditions/snow-and-weather-report.aspx","referringURL":null,"sysEnv":null,"breadCrumbs":["whistler blackcomb","the mountain","mountain conditions","Snow and Weather Report"],"language":null,"geoRegion":[],"publisher":null},"attributes":{"resort":"whistler blackcomb","reportSuite":null,"testVariant":null,"weather":{"precipitation":{"total24hr":null,"total48hr":null,"total7d":null,"overnightTotal":null,"seasonTotal":null,"midMtnDepth":null},"forecast":{"todayHigh":null,"todayLow":null,"todayCond":null,"tmrwHigh":null,"tmrwLow":null,"tmrwCond":null},"terrain":{"runsOpen":null,"liftsOpen":null,"acresOpen":null,"percentOpen":null}},"pageVendorVariables":[]}},"user":{"profile":{"profileInfo":{"name":null,"userName":null,"email":null,"etSubID":null,"ecID":null,"rposID":null,"language":null,"returning":null,"facebookID":null,"twitterID":null,"passRecommendation":null},"address":{"line1":null,"line2":null,"city":null,"stateProvince":null,"postalCode":null,"country":null}},"segment":{"age":null,"segment":null,"gender":null,"passType":null},"attributes":{"booking":{"bookingUserCity":null,"bookingUserState":null,"bookingUserZip":null,"bookingUserCountry":null},"authenticationStatus":null,"marketing":{"liftTickets":{"startDate":null,"endDate":null},"seasonPass":{"startDate":null,"endDate":null},"rentals":{"startDate":null,"endDate":null},"lodging":{"startDate":null,"endDate":null}}}},"products":{"lineItems":[]},"components":[],"cart":{"price":{"cartTotal":null,"currency":null},"lineItems":[]},"transaction":{"transactionID":null,"paymentType":null,"total":{"currency":null,"subTotal":null,"priceWithTax":null,"tax":null,"transactionTotal":null,"voucherCode":null,"voucherDiscount":null,"productTotal":null,"insuranceTotal":null},"attributes":{"bookingCheckin":null,"bookingCheckout":null,"bookingNights":null,"bookingWindow":null,"bookingTravelers":null,"bookingAdults":null,"bookingSeniors":null,"bookingChildren":null},"lineItems":[]},"componentVendorVariables":{},"ddoConfiguration":{"ddoIsEnabled":true,"ddoEndpointUrl":"https://ddo.vailresorts.com/api/orchestrators/DDO-In-Orchestrator"}}</script>
# <script src="/assets/bundles/core?v=wPejZyoZcg6xxEPJ1NTbgu2xrk4YDXRm7D50j7rd2ns1"></script>
# <script>var my_jquery = jQuery;</script>
# <script data-accountid="15853" data-secret="rebm6wrjqmwjrp9t9lno" id="navis-fusion-loader" src="https://assets.navisperformance.com/NWRC/Fusion/navis-fusion-loader.js"></script>
# <script src="//anpl.snow.com/js/prod/whistlerblackcomb/AdobeVisitorAPI.js"></script>
# <script async="" src="//anpl.snow.com/js/prod/whistlerblackcomb/whistlerblackcomb.js"></script>
# <!-- Stylesheets -->
# <link href="/Assets/css/sites/whistlerblackcomb/main.bundle.css" rel="stylesheet" type="text/css"/>
# <link href="/Assets/css/vendor/slick/slick.css" rel="stylesheet" type="text/css"/>
# <link href="/Assets/css/sites/whistlerblackcomb/content.bundle.css" rel="stylesheet" type="text/css"/>
# <link href="/Assets/css/vendor/bootstrap-datetime/bootstrap-datetimepicker-build.css" rel="stylesheet" type="text/css"/>
# <link href="/Assets/css/sites/whistlerblackcomb/header.bundle.css" rel="stylesheet" type="text/css"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/headerWeather.css" rel="stylesheet" type="text/css"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/login.css" rel="stylesheet" type="text/css"/>
# <link href="/Assets/css/sites/whistlerblackcomb/hero.bundle.css" rel="stylesheet" type="text/css"/>
# <link href="/Assets/css/vendor/typekit/typekit.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/snowReport.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/tabbedContainer.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/forecast.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/liveTemperature.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/freezingLevel.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/tabbedBookingWidgetMyEpicGear.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/sharedUI/numberCountInputReact.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/addToCartModal.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/sharedUI/errorModal.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/vendor/slick/slick.min.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/vendor/slick/slick-theme.min.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/vendor/vivify/vivify.min.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <link href="/Assets/css/sites/whistlerblackcomb/components/flipInCards.css" media="print" onload="this.media='all';this.onload=null;" rel="stylesheet"/>
# <!-- END HEAD Delivery -->
# <script defer="" src="/dist/runtime.bundle.b781ab2df2e4b398a7a0.js"></script><script defer="" src="/dist/vendor.bundle.4c28c6c220ec063dbedb.js"></script><script defer="" src="/dist/bootstrap.bundle.490f01536e572967a60b.js"></script><script defer="" src="/dist/index.bundle.726ed5ee05bf432aa105.js"></script>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch","rua.ceh":"false","rua.ueh":"false","rua.ieh.st":"0"}]);</script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="CBZXR-88838-45Y37-EY349-HXDK7",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"CBZXR-88838-45Y37-EY349-HXDK7";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="e2g54caxyzxfgzypicqa-f-bcc7bdc8b-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"39","ak.cp":"607092","ak.ai":parseInt("395541",10),"ak.ol":"0","ak.cr":24,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"a68aaad1","ak.r":43963,"ak.a2":n,"ak.m":"a","ak.n":"essl","ak.bpcip":"38.141.222.0","ak.cport":52122,"ak.gh":"104.88.207.212","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.0rtt.ed":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1729052832","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"97","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.0rtt.ed","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
# <body class="personality_canvas personality_canvas--option_1" data-resort="whistlerblackcomb" data-serverdatetime="10/15/2024 10:27:12 PM" data-session-active="false" data-session-time="60" data-user-ampid="" data-user-authentication-status="logged out" data-user-ecid="" data-user-passholder-status="" data-user-rposid="0" style="opacity: 0;">
# <div class="body__overlay" id="bodyOverlay"></div>
# <a aria-label="Skip to main content" class="skip-nav sr-only sr-only-focusable" href="#body-content" tabindex="0">Skip to main content</a>
# <header data-component-id="c00_Header" data-component-name="hdrHeader" id="c00_Header_1" role="banner">
# <nav class="main_nav" data-track="loaded" data-userisemreligible="" id="mainNav" role="navigation">
# <div class="container main_nav__container" id="mainNavInner">
# <div class="main_nav__resorts">
# <a class="main_nav__resort_logo icon-resorts-logo-whistlerblackcomb" data-component-element="hdrLogo" data-track="click" href="/" title=""> <span class="sr-only main_nav__resort_logo_text">whistlerblackcomb homepage</span>
# </a>
# </div>
# <div class="main_nav__level1">
# <span class="main_nav__border"></span>
# <div class="main_nav__level1_list siteselector">
# <div class="main_nav__level1_item visible-lg level1_icon" tabindex="-1">
# <a class="level1" data-component-element="hdrMenuL1ResortNav" data-track="click mouseenter" href="javascript:void(0);" tabindex="0">
# <span class="sr-only">Choose a Resort</span>
# <span aria-hidden="true" class="icon-arrow-dropdown-down"></span>
# </a>
# <div class="main_nav__dropdown navdropdown--light">
# <div class="main_nav__dropdown__arrow">
# <div class="main_nav__dropdown__arrow-container"></div>
# </div>
# <div class="main_nav__dropdown__content main_nav__focusable_element main_nav__regions_resorts icon_menu" tabindex="0">
# <div class="main_nav__resort_list">
# <div class="main_nav__regions_resorts__panel">
# <ul class="main_nav__regions_resorts__panel__body--resortGroup" id="headerResortsCollapse">
# <li class="main_nav__regions_resorts__panel__list--resorts">
# <a aria-expanded="false" class="main_nav__regions_resorts__panel__heading--resorts" data-component-element="regionHeaderLink" data-region-name="Rockies" data-toggle="collapse" data-track="click" href="#headerResortCollapse0" id="headerresortheading0">
# <div class="panel-title region--header">
#                                         Rockies
#                                         <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-plus"></i>
# <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-minus"></i>
# </div>
# </a>
# <div aria-labelledby="headerresortheading0" class="panel-collapse collapse in main_nav__regions_resorts__panel__body--resorts" data-region-index="0" id="headerResortCollapse0">
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-vail" data-resort-name="Vail" data-track="click" data-x-coordinate="666" data-y-coordinate="214" href="https://www.vail.com/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Vail</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-beaver-creek" data-resort-name="Beaver Creek" data-track="click" data-x-coordinate="653" data-y-coordinate="216" href="https://www.beavercreek.com/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Beaver Creek</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-breck" data-resort-name="Breckenridge" data-track="click" data-x-coordinate="678" data-y-coordinate="224" href="https://www.breckenridge.com/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Breckenridge</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-parkcity" data-resort-name="Park City" data-track="click" data-x-coordinate="477" data-y-coordinate="126" href="https://www.parkcitymountain.com/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Park City</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-keystone" data-resort-name="Keystone" data-track="click" data-x-coordinate="688" data-y-coordinate="218" href="https://www.keystoneresort.com/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Keystone</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-crested-butte" data-resort-name="Crested Butte" data-track="click" data-x-coordinate="629" data-y-coordinate="243" href="https://www.skicb.com/" rel="noopener noreferrer" target="_blank" title="Crested Butte"> <span class="main_nav__resort_list__item--name">Crested Butte</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# </div>
# </li>
# <li class="main_nav__regions_resorts__panel__list--resorts">
# <a aria-expanded="false" class="main_nav__regions_resorts__panel__heading--resorts collapsed" data-component-element="regionHeaderLink" data-region-name="West" data-toggle="collapse" data-track="click" href="#headerResortCollapse1" id="headerresortheading1">
# <div class="panel-title region--header">
#                                         West
#                                         <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-plus"></i>
# <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-minus"></i>
# </div>
# </a>
# <div aria-labelledby="headerresortheading1" class="panel-collapse collapse main_nav__regions_resorts__panel__body--resorts" data-region-index="1" id="headerResortCollapse1">
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-heavenly" data-resort-name="Heavenly" data-track="click" data-x-coordinate="551" data-y-coordinate="213" href="https://www.skiheavenly.com/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Heavenly</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-northstar" data-resort-name="Northstar" data-track="click" data-x-coordinate="543" data-y-coordinate="198" href="https://www.northstarcalifornia.com/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Northstar</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-kirkwood" data-resort-name="Kirkwood" data-track="click" data-x-coordinate="543" data-y-coordinate="222" href="https://www.kirkwood.com/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Kirkwood</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-stevens-pass" data-resort-name="Stevens Pass" data-track="click" data-x-coordinate="605" data-y-coordinate="-42" href="https://www.stevenspass.com/" rel="noopener noreferrer" target="_blank" title="Stevens Pass"> <span class="main_nav__resort_list__item--name">Stevens Pass</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# </div>
# </li>
# <li class="main_nav__regions_resorts__panel__list--resorts">
# <a aria-expanded="false" class="main_nav__regions_resorts__panel__heading--resorts collapsed" data-component-element="regionHeaderLink" data-region-name="Northeast" data-toggle="collapse" data-track="click" href="#headerResortCollapse2" id="headerresortheading2">
# <div class="panel-title region--header">
#                                         Northeast
#                                         <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-plus"></i>
# <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-minus"></i>
# </div>
# </a>
# <div aria-labelledby="headerresortheading2" class="panel-collapse collapse main_nav__regions_resorts__panel__body--resorts" data-region-index="2" id="headerResortCollapse2">
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-stowe" data-resort-name="Stowe" data-track="click" data-x-coordinate="578" data-y-coordinate="138" href="https://www.stowe.com/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Stowe</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-okemo" data-resort-name="Okemo" data-track="click" data-x-coordinate="591" data-y-coordinate="210" href="https://www.okemo.com/" rel="noopener noreferrer" target="_blank" title="Okemo"> <span class="main_nav__resort_list__item--name">Okemo</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-mtsnow" data-resort-name="Mount Snow" data-track="click" data-x-coordinate="589" data-y-coordinate="236" href="https://www.mountsnow.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Mount Snow</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-hunter" data-resort-name="Hunter" data-track="click" data-x-coordinate="561" data-y-coordinate="296" href="https://www.huntermtn.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Hunter</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-attitashmountain" data-resort-name="Attitash Mountain" data-track="click" data-x-coordinate="643" data-y-coordinate="159" href="https://www.attitash.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Attitash Mountain</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-wildcatmountain" data-resort-name="Wildcat Mountain" data-track="click" data-x-coordinate="643" data-y-coordinate="150" href="https://www.skiwildcat.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Wildcat Mountain</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-mount-sunapee" data-resort-name="Mount Sunapee" data-track="click" data-x-coordinate="629" data-y-coordinate="197" href="https://www.mountsunapee.com/" rel="noopener noreferrer" target="_blank" title="Mount Sunapee"> <span class="main_nav__resort_list__item--name">Mount Sunapee</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-crotchedmountain" data-resort-name="Crotched Mountain" data-track="click" data-x-coordinate="644" data-y-coordinate="215" href="https://www.crotchedmtn.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Crotched Mountain</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# </div>
# </li>
# <li class="main_nav__regions_resorts__panel__list--resorts">
# <a aria-expanded="false" class="main_nav__regions_resorts__panel__heading--resorts collapsed" data-component-element="regionHeaderLink" data-region-name="Mid-Atlantic" data-toggle="collapse" data-track="click" href="#headerResortCollapse3" id="headerresortheading3">
# <div class="panel-title region--header">
#                                         Mid-Atlantic
#                                         <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-plus"></i>
# <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-minus"></i>
# </div>
# </a>
# <div aria-labelledby="headerresortheading3" class="panel-collapse collapse main_nav__regions_resorts__panel__body--resorts" data-region-index="3" id="headerResortCollapse3">
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-libertymountain" data-resort-name="Liberty Mountain" data-track="click" data-x-coordinate="668" data-y-coordinate="173" href="https://www.libertymountainresort.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Liberty Mountain</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-roundtopmountain" data-resort-name="Roundtop Mountain" data-track="click" data-x-coordinate="688" data-y-coordinate="154" href="https://www.skiroundtop.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Roundtop Mountain</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-whitetail" data-resort-name="Whitetail" data-track="click" data-x-coordinate="645" data-y-coordinate="177" href="https://www.skiwhitetail.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Whitetail</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-jackfrostbigboulder" data-resort-name="Jack Frost" data-track="click" data-x-coordinate="721" data-y-coordinate="88" href="https://www.jfbb.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Jack Frost</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-jackfrostbigboulder" data-resort-name="Big Boulder" data-track="click" data-x-coordinate="722" data-y-coordinate="99" href="https://www.jfbb.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Big Boulder</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-hiddenvalleypa" data-resort-name="Hidden Valley PA" data-track="click" data-x-coordinate="592" data-y-coordinate="175" href="https://www.hiddenvalleyresort.com/"> <span class="main_nav__resort_list__item--name">Hidden Valley PA</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-laurelmountain" data-resort-name="Laurel Mountain" data-track="click" data-x-coordinate="598" data-y-coordinate="160" href="https://www.laurelmountainski.com/"> <span class="main_nav__resort_list__item--name">Laurel Mountain</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-sevensprings" data-resort-name="Seven Springs" data-track="click" data-x-coordinate="583" data-y-coordinate="175" href="https://www.7springs.com/"> <span class="main_nav__resort_list__item--name">Seven Springs</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# </div>
# </li>
# <li class="main_nav__regions_resorts__panel__list--resorts">
# <a aria-expanded="false" class="main_nav__regions_resorts__panel__heading--resorts collapsed" data-component-element="regionHeaderLink" data-region-name="Midwest" data-toggle="collapse" data-track="click" href="#headerResortCollapse4" id="headerresortheading4">
# <div class="panel-title region--header">
#                                         Midwest
#                                         <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-plus"></i>
# <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-minus"></i>
# </div>
# </a>
# <div aria-labelledby="headerresortheading4" class="panel-collapse collapse main_nav__regions_resorts__panel__body--resorts" data-region-index="4" id="headerResortCollapse4">
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-wilmot" data-resort-name="Wilmot Mountain" data-track="click" data-x-coordinate="603" data-y-coordinate="163" href="http://www.wilmotmountain.com" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Wilmot Mountain</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-aftonalps" data-resort-name="Afton Alps" data-track="click" data-x-coordinate="485" data-y-coordinate="89" href="http://www.aftonalps.com/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Afton Alps</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-mtbrighton" data-resort-name="Mt Brighton" data-track="click" data-x-coordinate="713" data-y-coordinate="152" href="http://www.mtbrighton.com/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Mt Brighton</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-alpinevalley" data-resort-name="Alpine Valley" data-track="click" data-x-coordinate="773" data-y-coordinate="191" href="https://www.alpinevalleyohio.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Alpine Valley</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-bostonmillsbrandywine" data-resort-name="Boston Mills" data-track="click" data-x-coordinate="763" data-y-coordinate="198" href="https://www.bmbw.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Boston Mills</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-bostonmillsbrandywine" data-resort-name="Brandywine" data-track="click" data-x-coordinate="763" data-y-coordinate="198" href="https://www.bmbw.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Brandywine</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-madrivermountain" data-resort-name="Mad River Mountain" data-track="click" data-x-coordinate="718" data-y-coordinate="220" href="https://www.skimadriver.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Mad River Mountain</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-hiddenvalley" data-resort-name="Hidden Valley" data-track="click" data-x-coordinate="537" data-y-coordinate="298" href="https://www.hiddenvalleyski.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Hidden Valley</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-snowcreek" data-resort-name="Snow Creek" data-track="click" data-x-coordinate="435" data-y-coordinate="266" href="https://www.skisnowcreek.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Snow Creek</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-paolipeaks" data-resort-name="Paoli Peaks" data-track="click" data-x-coordinate="653" data-y-coordinate="286" href="https://www.paolipeaks.com/" target="|Custom"> <span class="main_nav__resort_list__item--name">Paoli Peaks</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# </div>
# </li>
# <li class="main_nav__regions_resorts__panel__list--resorts">
# <a aria-expanded="false" class="main_nav__regions_resorts__panel__heading--resorts collapsed" data-component-element="regionHeaderLink" data-region-name="Canada" data-toggle="collapse" data-track="click" href="#headerResortCollapse5" id="headerresortheading5">
# <div class="panel-title region--header">
#                                         Canada
#                                         <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-plus"></i>
# <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-minus"></i>
# </div>
# </a>
# <div aria-labelledby="headerresortheading5" class="panel-collapse collapse main_nav__regions_resorts__panel__body--resorts" data-region-index="5" id="headerResortCollapse5">
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-whistlerblackcomb" data-resort-name="Whistler Blackcomb" data-track="click" data-x-coordinate="581" data-y-coordinate="296" href="/" rel="noopener noreferrer" target="_blank" title="Whistler Blackcomb"> <span class="main_nav__resort_list__item--name">Whistler Blackcomb</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# </div>
# </li>
# <li class="main_nav__regions_resorts__panel__list--resorts">
# <a aria-expanded="false" class="main_nav__regions_resorts__panel__heading--resorts collapsed" data-component-element="regionHeaderLink" data-region-name="Australia" data-toggle="collapse" data-track="click" href="#headerResortCollapse6" id="headerresortheading6">
# <div class="panel-title region--header">
#                                         Australia
#                                         <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-plus"></i>
# <i aria-hidden="true" class="main_nav__regions_resorts__panel__heading__icon icon-global-minus"></i>
# </div>
# </a>
# <div aria-labelledby="headerresortheading6" class="panel-collapse collapse main_nav__regions_resorts__panel__body--resorts" data-region-index="6" id="headerResortCollapse6">
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-perisher" data-resort-name="Perisher" data-track="click" data-x-coordinate="574" data-y-coordinate="278" href="https://www.perisher.com.au/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Perisher</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-fallscreek" data-resort-name="Falls Creek" data-track="click" data-x-coordinate="557" data-y-coordinate="286" href="https://www.skifalls.com.au/" rel="noopener noreferrer" target="_blank"> <span class="main_nav__resort_list__item--name">Falls Creek</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# <div class="main_nav__regions_resorts__panel__list">
# <a class="main_nav__resort_list__item resortselect--v1" data-component-element="resortFinderLink" data-icon-class="icon-resorts-bug-hotham" data-resort-name="Hotham" data-track="click" data-x-coordinate="551" data-y-coordinate="291" href="https://www.mthotham.com.au/"> <span class="main_nav__resort_list__item--name">Hotham</span>
# <span class="sr-only">Website , opens in a new window</span>
# </a> </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="main_nav__regions_resorts__map">
# <div class="selected_resort_pin">
# <i aria-hidden="true" class="resort_icon"></i>
# </div>
# <div class="region_map">
# <div class="region_map_0">
# <img alt="" class="s7-responsive" data-aem-asset-id="1935808445" data-lazyload="menu" data-src="https://scene7.vailresorts.com/is/image/vailresorts/region_resort_map-Rockies?fmt=png-alpha&amp;resMode=sharp2"/> </div>
# <div class="region_map_1 hidden">
# <img alt="" class="s7-responsive" data-aem-asset-id="1928200303" data-lazyload="menu" data-src="https://scene7.vailresorts.com/is/image/vailresorts/region_resort_map-West?fmt=png-alpha&amp;resMode=sharp2"/> </div>
# <div class="region_map_2 hidden">
# <img alt="" class="s7-responsive" data-aem-asset-id="1191132690" data-lazyload="menu" data-src="https://scene7.vailresorts.com/is/image/vailresorts/region_resort_map-Northeast?fmt=png-alpha&amp;resMode=sharp2"/> </div>
# <div class="region_map_3 hidden">
# <img alt="Mid-Atlantic Region Map" class="s7-responsive" data-aem-asset-id="2111952212" data-lazyload="menu" data-src="https://scene7.vailresorts.com/is/image/vailresorts/20221223_mid-atlantic-region_map_001?resMode=sharp2&amp;w=1740&amp;h=1000"/> </div>
# <div class="region_map_4 hidden">
# <img alt="" class="s7-responsive" data-aem-asset-id="386891963" data-lazyload="menu" data-src="https://scene7.vailresorts.com/is/image/vailresorts/region_resort_map-Midwest?fmt=png-alpha&amp;resMode=sharp2"/> </div>
# <div class="region_map_5 hidden">
# <img alt="" class="s7-responsive" data-aem-asset-id="856123918" data-lazyload="menu" data-src="https://scene7.vailresorts.com/is/image/vailresorts/region_resort_map-Canada?fmt=png-alpha&amp;resMode=sharp2"/> </div>
# <div class="region_map_6 hidden">
# <img alt="" class="s7-responsive" data-aem-asset-id="326172687" data-lazyload="menu" data-src="https://scene7.vailresorts.com/is/image/vailresorts/region_resort_map-Australia?fmt=png-alpha&amp;resMode=sharp2"/> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="main_nav__level1_list">
# <div class="main_nav__level1_item hidden-md hidden-sm hidden-xs">
# <a aria-expanded="false" class="level1" data-component-element="hdrMenuL1" data-track="click" href="#main_nav__dropdown__1">Explore the Resort</a>
# <!-- Dropdown w/arrow -->
# <div class="main_nav__dropdown" id="main_nav__dropdown__1">
# <div class="main_nav__dropdown__arrow">
# <div class="main_nav__dropdown__arrow-container"></div>
# </div>
# <div class="main_nav__dropdown__content main_nav__focusable_element" tabindex="0">
# <div class="main_nav__column_border"></div>
# <div class="main_nav__dropdown__content-column">
# <h2 class="level2 main_nav__level2_heading" data-component-element="hdrMenuL2" data-track="click">
# <span class="sr-only">Section Title</span>
#                                                 About the Resort
#                                             </h2>
# <ul class="main_nav__level3_list">
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/about-the-resort/hours-of-operation.aspx" title="">Hours of Operation</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/about-the-resort/guest-services.aspx" title="">Guest Services</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/about-the-resort/whistler-winter.aspx" title="">Whistler in Winter</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/about-the-resort/whistler-in-summer.aspx" title="">Whistler in Summer</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/about-the-resort/accessibility-in-whistler.aspx" title="">Accessibility in Whistler</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/about-the-resort/whistler-family-winter.aspx" title="">For The Family</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/about-the-resort/exceptional-experiences.aspx" title="">Exceptional Experiences</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/about-the-resort/groups-and-weddings.aspx" title="">Groups and Weddings</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="http://blog.whistlerblackcomb.com/" rel="noopener noreferrer" target="_blank" title="">The Blog</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="https://whistlerblackcomb.zendesk.com/hc/en-us" rel="noopener noreferrer" target="_blank" title="">Help Center</a>
# </div>
# </ul>
# </div>
# <div class="main_nav__dropdown__content-column">
# <h2 class="level2 main_nav__level2_heading" data-component-element="hdrMenuL2" data-track="click">
# <span class="sr-only">Section Title</span>
#                                                 About The Village
#                                             </h2>
# <ul class="main_nav__level3_list">
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/the-village/village-overview.aspx" title="">Village Overview</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/the-village/dining.aspx" title="">Dining</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/the-village/apres-and-nightlife.aspx" title="">Apres and Nightlife</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/the-village/shopping.aspx" title="">Shopping</a>
# </div>
# <div class="main_nav__level3_item">
# <a class="level3" data-component-element="hdrMenuL3" data-track="click" href="/explore-the-resort/about-the-resort/winter-gear-guide.aspx" title="">Winter Gear Guide</a>
# </div>
# <div class="main_nav__level3_item">
# ...
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="https://www.facebook.com/whistlerblackcomb" rel="noopener noreferrer" target="_blank" title="Facebook"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="1751512286" data-src="https://scene7.vailresorts.com/is/image/vailresorts/facebook_FINAL?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="https://www.instagram.com/whistlerblackcomb/" rel="noopener noreferrer" target="_blank" title="Instagram"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="413894280" data-src="https://scene7.vailresorts.com/is/image/vailresorts/instagram_FINAL?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="https://twitter.com/WhistlerBlckcmb" rel="noopener noreferrer" target="_blank" title="Twitter"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="77019125" data-src="https://scene7.vailresorts.com/is/image/vailresorts/twitter_FINAL_1?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="https://www.youtube.com/user/WhistlerBlackcombMtn" rel="noopener noreferrer" target="_blank" title="YouTube"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="1342154385" data-src="https://scene7.vailresorts.com/is/image/vailresorts/youtube_FINAL_1?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="http://pinterest.com/whistlerblckcmb/" rel="noopener noreferrer" target="_blank" title="Pintrest"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="2020532094" data-src="https://scene7.vailresorts.com/is/image/vailresorts/pinterest_FINAL?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="/" title="Whistler Blackcomb Home Page"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="694325502" data-src="https://scene7.vailresorts.com/is/image/vailresorts/Canada_Footer_Flag?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="/international/quebec.aspx" title="Quebec"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="2019885496" data-src="https://scene7.vailresorts.com/is/image/vailresorts/Quebec_Footer_Flag?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="/international/australia.aspx" title="Australia"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="1220908701" data-src="https://scene7.vailresorts.com/is/image/vailresorts/Australia_Footer_Flag?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="/international/usa.aspx" title="USA"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="893773775" data-src="https://scene7.vailresorts.com/is/image/vailresorts/US_Footer_Flag?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="/international/uk.aspx" title="UK"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="1507129851" data-src="https://scene7.vailresorts.com/is/image/vailresorts/UK_Footer_Flag?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="/international/spanish.aspx" title="Mexico"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="691939915" data-src="https://scene7.vailresorts.com/is/image/vailresorts/Mexico_Footer_Flag?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="/international/german.aspx"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="1090850820" data-src="https://scene7.vailresorts.com/is/image/vailresorts/Germany_Footer_Flag?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="/international/french.aspx"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="1525244966" data-src="https://scene7.vailresorts.com/is/image/vailresorts/France_Footer_Flag?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="/international/portuguese.aspx"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="1068795440" data-src="https://scene7.vailresorts.com/is/image/vailresorts/Brazil_Footer_Flag?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="/international/sweden.aspx"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="1787955757" data-src="https://scene7.vailresorts.com/is/image/vailresorts/Sweden_Footer_Flag?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# <li class="footer__social__icons__item">
# <a data-component-element="ftrLink" data-track="click" href="/international/denmark.aspx"><div class="footer__image--social"><img alt="" class="s7-responsive" data-aem-asset-id="1449615540" data-src="https://scene7.vailresorts.com/is/image/vailresorts/Denmark_Footer_Flag?fmt=png-alpha&amp;resMode=sharp2"/></div></a> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12 footer__legal">
# <i class="icon-resorts-logo-whistlerblackcomb">
# <span class="sr-only">whistlerblackcomb Logo</span>
# </i>
# <div class="sctexteditor--copyright">© 2024 Whistler Blackcomb Holdings, Inc.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <input id="csrfToken" type="hidden" value="AW0QW68zQQ9B0LgaKyzqoXWBqikcc-39683jrQ81EiZ_z8mczfqtbHELZw1Ff0qhRjDpU2AwFHiS42FJSSX3uQABYsY1:7phu-j7TG1etDRUkgUwPAxeQbOE9gaQXMwnvfZ1YSHEmWAMBT8RgXU8QkT6xJTf-fMAGmmHNcsO2N5rlrVpgM5p99qo1"/>
# <div class="global_modal" role="dialog">
# <div class="global_modal__container container" data-component-id="c31_Modal_Component" data-component-name="mdlGlobalModal" id="c31_Modal_Component_1">
# <div class="global_modal__controls">
# <a class="global_modal__close" href="#" role="button">
# <span class="sr-only">Close</span>
# </a>
# </div>
# <div class="global_modal__content col-xs-12"></div>
# </div>
# <div aria-hidden="true" class="global_modal__overlay" tabindex="-1"></div>
# </div>
# <script id="loading_spinner_template" type="text/template">
#     <div class="loading_spinner">
#         <div class="loading_spinner__overlay"></div>
#         <span class="loading_spinner__loading sr-only" tabindex="0">Loading</span>
#         <% if (options && options.loadingMessage) { %>
#         <span class="loading_spinner__message small"><%= options.loadingMessage %></span>
#         <% } %>
#     </div>
# </script>
# <script type="text/javascript">
#     var queryParams = new URLSearchParams(window.location.search);
#     var isEpicMixPageView = queryParams.get("em") === "1";
#     if (isEpicMixPageView && !sessionStorage.getItem("epicmix")) {
#         sessionStorage.setItem("epicmix", isEpicMixPageView);
#     }
# </script>
# <script id="product_reminder_template" type="text/template">
#     <div class="product_reminder_modal"
#         data-component-element="mdlPersistentCart"
#         data-component-nights-elapsed="0"
#         data-track="shown">
#         <div class="product_reminder_modal__content col-xs-12">
#             <div class="sctexteditor">
#                 <h2 class="small small--alt2 product_reminder_modal__title large col-xs-12"></h2>
#                 <p class="product_reminder_modal__description col-xs-12"></p>
#             </div>
#             <div class="sctexteditor--bold">
#                 <ul class="product_reminder_modal__list col-xs-12">
#                 </ul>
#             </div>
#         </div>
#         <div class="product_reminder_modal__controls col-xs-12">
#             <a class="product_reminder_modal__option_checkout primaryCTA"
#                href=""
#                title="Checkout"
#                data-component-element="mdlPersistentCartCheckoutButton"
#                data-track="click">Checkout</a>
#             <a class="product_reminder_modal__option_continue linkCTA left_arrow" href="#" title="Continue Shopping">Continue Shopping</a>
#         </div>
#     </div>
# </script>
# <script type="module">
#     FR.productReminderIsEnabled = false;
# </script>
# <script id="session_expired_template" type="text/template">
#     <div class="session_expired_modal"
#          data-component-element="mdlSessionExpired"
#          data-track="shown">
#         <div class="session_expired_modal__content col-xs-12">
#             <div class="sctexteditor">
#                 <h2 class="small small--alt2 session_expired_modal__title large col-xs-12">YOUR SESSION HAS EXPIRED DUE TO INACTIVITY</h2>
#                 <div class="session_expired_modal__description col-xs-12">In order to protect your privacy, we have expired your session. Don't worry, we saved the items in your cart and they will remain there for up to 30 days. Select "Continue" to return to your cart and keep shopping.</div>
#             </div>
#         </div>
#         <div class="session_expired_modal__controls col-xs-12">
#             <button class="session_expired_modal__button primaryCTA primaryCTA--medium" data-track="click">Continue</button>
#         </div>
#     </div>
# </script>
# <script id="checkout_session_expired_template" type="text/template">
#     <div class="session_expired_modal"
#          data-component-element="mdlSessionExpired"
#          data-track="shown">
#         <div class="session_expired_modal__content col-xs-12">
#             <div class="sctexteditor">
#                 <h2 class="small small--alt2 session_expired_modal__title large col-xs-12">YOUR SESSION HAS EXPIRED DUE TO INACTIVITY</h2>
#                 <div class="session_expired_modal__description col-xs-12">In order to protect your privacy, we have expired your session. Select &ldquo;Continue&rdquo; to keep shopping.</div>
#             </div>
#         </div>
#         <div class="session_expired_modal__controls col-xs-12">
#             <button class="session_expired_modal__button primaryCTA primaryCTA--medium" data-track="click">View Cart</button>
#         </div>
#     </div>
# </script>
# <script id="session_warning_template" type="text/template">
#     <div class="session_warning_modal"
#          data-component-element="mdlSessionWarning"
#          data-track="shown">
#         <div class="session_warning_modal__content col-xs-12">
#             <div class="sctexteditor">
#                 <h2 class="small small--alt2 session_warning_modal__title large col-xs-12">YOUR SESSION WILL EXPIRE IN 10 MINUTES</h2>
#                 <div class="session_warning_modal__description col-xs-12">You&rsquo;ve been inactive for a while. For your security, we&rsquo;ll save the items in your cart but automatically end your session in 10 minutes. Select &ldquo;Continue&rdquo; to keep shopping.</div>
#             </div>
#         </div>
#         <div class="session_warning_modal__controls col-xs-12">
#             <button class="session_warning_modal__button primaryCTA primaryCTA--medium">Continue</button>
#         </div>
#     </div>
# </script>
# <script type="module">
#     FR.scene7.baseUrl = 'https://scene7.vailresorts.com';
#     FR.scene7.maxWidth = 4000;
#     FR.scene7.maxHeight = 4000;
#
#     FR.digitalApiBaseUrl = 'https://digital.snow.com/api/';
#
#     $.scene7.responsive();
# </script>
# <script src="//static.queue-it.net/script/queueclient.min.js" type="text/javascript"></script>
# <script data-queueit-c="vailresorts" data-queueit-intercept="true" data-queueit-intercept-domain="www.whistlerblackcomb.com" src="//static.queue-it.net/script/queueconfigloader.min.js" type="text/javascript">
# </script>
# <script type="text/javascript">
#     window.global = window.global || {};
#     window.global.analytics = window.global.analytics || {}
#     window.global.analytics.snowRequestIsEnabled = 'true' === 'true';
#     window.global.analytics.snowRequestExpiration = parseInt('30');
#     window.global.analytics.snowRequestCoordinates = { latitude: parseFloat('0'), longitude: parseFloat('0') };
#     $(window).trigger('anpl_globalAnalyticsReady');
#
#     window.global.adobeTarget = window.global.adobeTarget || {};
#     window.global.adobeTarget.ttMETAEventTriggered = [];
#
#     window.ttMETANotified = [];
# </script>
# <script src="/Assets/js/services/oneTrustTracking.js" type="text/javascript"></script>
# <script type="text/javascript">
#     window._mfq = window._mfq || [];
#     (function () {
#         var mf = document.createElement("script");
#         mf.type = "text/javascript"; mf.async = true;
#         mf.src = "//cdn.mouseflow.com/projects/da786a13-4027-4541-a33f-24379fc29d42.js";
#         document.getElementsByTagName("head")[0].appendChild(mf);
#         $(window).trigger('mfqLoaded');
#     })();
# </script>
# <script type="module">
#     if (window.ttMETANotified) {
#         FR.sendTestsToMouseflow(_.pluck(window.ttMETANotified, 'responseTokens'));
#     }
#
#     function succeeded(event) {
#         const responseTokens = _.uniq(event && event.detail && event.detail.responseTokens, true, 'activity.id');
#         FR.sendTestsToMouseflow(responseTokens);
#     }
#
#     document.addEventListener('at-request-succeeded', succeeded);
# </script>
# <div id="react-modal"></div>
# <!-- load scripts after views to ensure they are all included  -->
# <script defer="" src="/dist/bookingWidgets.tabbedBookingWidgetMyEpicGear.bundle.4c2430d520e43511fc18.js"></script>
# <script defer="" src="/dist/checkout.productReminderModal.bundle.96df81635210e5843535.js"></script>
# <script defer="" src="/dist/checkout.sessionExpiredModal.bundle.163cdb337df86c89e7ea.js"></script>
# <script defer="" src="/dist/checkout.sessionWarningModal.bundle.1d3e63ec7bb2a95a7829.js"></script>
# <script defer="" src="/dist/header.header.bundle.dc9a8e476bd40b7d7e6e.js"></script>
# <script defer="" src="/dist/header.headerWeather.bundle.1ba9e44627aea85b8975.js"></script>
# <script defer="" src="/dist/layouts.hero-full.bundle.15e091ebfe4c19469e7e.js"></script>
# <script defer="" src="/dist/login.bundle.2a35efe5c768db239145.js"></script>
# <script defer="" src="/dist/mountain.freezingLevel.bundle.365ec42b9f1dfdc9a853.js"></script>
# <script defer="" src="/dist/mountain.liveTemperature.bundle.6ef6c390b5f19cb50b7f.js"></script>
# <script defer="" src="/dist/mountain.snowReport.bundle.0a08199645b524679bff.js"></script>
# <script defer="" src="/dist/mountain.weatherForecast.bundle.6f6fafd306b74bcd2f4e.js"></script>
# <script defer="" src="/dist/multimedia.flipInCardComponent.bundle.656859ea2a7d32380969.js"></script>
# <script defer="" src="/dist/sharedUI.errorModal.bundle.a3f7a0faff071ee194b6.js"></script>
# <script defer="" src="/dist/sharedUI.globalModal.bundle.98027972973f69563409.js"></script>
# <script defer="" src="/dist/sharedUI.loadingSpinner.bundle.ed50a15bf39352e368cb.js"></script>
# <!-- END BODY Delivery -->
# </body>
# </html>

# %%
def get_data_subclass(data,data_string):
    #print(datapoint.find(class_=data_string).text)
    return data.find(class_=data_string).text



#select our live temperature values now




#go over the different weather stations displayed
for datapoint in soup.select('.live_temperature__station_container'):

    #find the name of the station
    station_string = datapoint.find(class_='live_temperature__station_name')
    #print(station_string.text.lstrip())
    station_name = station_string.text.lstrip().rstrip()
    
    #get the live temperature
    soup_string = datapoint.find(class_='live_temperature__international_only')
    #print(soup_string.text)
    #my_list = soup_string.text.split(" ")
    my_list = get_data_subclass(datapoint,'live_temperature__international_only').split(" ")

    temp = my_list[0]
    units = my_list[1]
    #print(my_list[0])
    #print(my_list[1])

    #figure out when it was last updated.
    updated_string = datapoint.find(class_='live_temperature__last_updated')
    updated = updated_string.text.lstrip().rstrip()

    #wind_string = datapoint.find(class_='icon-weather-windy')
    #wind = wind_string.text.lstrip().rstrip()

    print(f"The weather station {station_name} has temperature of {temp} with units {units}. {updated}")
# Out:
# The weather station Whistler Peak has temperature of -1 with units °C. Updated: 0 hrs 27 min ago
# The weather station Roundhouse has temperature of 1 with units °C. Updated: 0 hrs 27 min ago
# The weather station Pig Alley has temperature of 3 with units °C. Updated: 0 hrs 27 min ago
# The weather station Whistler Village has temperature of 10 with units °C. Updated: 0 hrs 27 min ago

# %% [markdown]
# Now trying to get from https://whistlerpeak.com

# %%
#more imports needed. Whistler Peak uses Javascript to load the temperatures, so we can't just use requests.get to 
#obtain the webpage. It won't update with the temperature values
import selenium as se
from selenium import webdriver

# %%
#because PhantomJS has been deprecated from 
#now we use the suggestions in https://stackoverflow.com/questions/48537028/selenium-how-to-use-headless-chrome-on-aws
#and https://stackoverflow.com/questions/48537028/selenium-how-to-use-headless-chrome-on-aws

#need a headless firefox browser to properly render things
def createHeadlessFirefoxBrowser():
     options = webdriver.FirefoxOptions()
     options.add_argument('--headless')
     return webdriver.Firefox(options=options)

browser = createHeadlessFirefoxBrowser()

browser.get("https://whistlerpeak.com/temps/")
html = browser.page_source
#soup = bs4.BeautifulSoup(html, 'lxml')
soup = bs4.BeautifulSoup(html, features="html.parser")
#a = soup.find('section', 'wrapper')

# %%
print(soup)
# Out:
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="#322D29" name="theme-color"/>
# <meta content="#322D29" media="(prefers-color-scheme: light)" name="theme-color"/>
# <meta content="#322D29" media="(prefers-color-scheme: dark)" name="theme-color"/>
# <title>Live Temps - Whistler Peak Weather Site - Whistler Blackcomb, BC, Canada</title>
# <meta content="Live Temps - whistlerpeak.com - Weather and Snow Conditions for Whistler Blackcomb" name="description"/>
# <meta content="whistler,blackcomb,mountains,webcams,weather,ski,snowboarding,snow,report,conditions,canada" name="keywords"/>
# <meta content="public" http-equiv="Cache-control"/>
# <link href="./apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="./apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="./apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="./apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="./apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="./apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="./apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="./apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="./apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="./android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="./favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="./favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="./favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="./manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="./ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.12.0-2/css/all.min.css" rel="stylesheet"/>
# <link href="../nav/css-nav-no-switch.css?CcJFDza8Pd" rel="stylesheet"/>
# <link href="../nav/css-nav.php?CcJFDza8Pd" rel="stylesheet"/>
# <link href="css-temps.css?CcJFDza8Pd" rel="stylesheet"/>
# <link href="../snow-widget/snow-widget-light.css?CcJFDza8Pd" rel="stylesheet"/>
# <script async="" src="//www.google-analytics.com/analytics.js"></script><script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script>
# </head>
# <body>
# <header>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-46285825-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <h1 class="logo">whistler peak</h1>
# <nav>
# <ul>
# <li class="desktop"><a href="https://whistlerpeak.com/bike/">Bike</a></li>
# <li class="desktop"><a href="https://whistlerpeak.com/cams/">Cams</a></li>
# <!-- <li class='desktop'><a href="https://whistlerpeak.com/choose/">Forecast</a></li> -->
# <li class="desktop"><a href="https://whistlerpeak.com/forecast/">Forecast</a></li>
# <li class="desktop"><a href="https://whistlerlifts.com/livelifts/">Lifts</a></li>
# <!-- <li class='desktop'><a href='https://whistlerruns.com/grooming/'>Runs</a></li> -->
# <!-- <li class='desktop'><a href="https://whistlerpeak.com/snow/">Snow</a></li> -->
# <li class="desktop"><a href="https://whistlerpeak.com/temps/">Temps</a></li>
# <li class="desktop"><a href="https://whistlerpeak.com/video/">Video</a></li>
# </ul>
# </nav>
# <input class="openSidebarMenu" id="openSidebarMenu" name="navToggle" type="checkbox"/>
# <label class="sidebarIconToggle" for="openSidebarMenu">
# <div class="spinner diagonal part-1"></div>
# <div class="spinner horizontal"></div>
# <div class="spinner diagonal part-2"></div>
# </label>
# <div id="sidebarMenu">
# <ul class="sidebarMenuInner small" style="gap: 0.5em;">
# <li id="support" style="padding: 1em;">About<span>This Project</span></li>
# <li id="bike" style="padding: 1em;">Bike<span>Park</span></li>
# <!-- <li id="backcountry">Backcountry<span>Report</span></li> -->
# <li id="roads" style="padding: 1em;">Cams<span>highway</span></li>
# <li id="cams" style="padding: 1em;">Cams<span>mountain</span></li>
# <li id="weather-top" style="padding: 1em;">Forecast<span>2248m•SF</span></li>
# <li id="forecast" style="padding: 1em;">Forecast<span>1800m•RWDI</span></li>
# <li id="weather" style="padding: 1em;">Forecast<span>1400m•SF</span></li>
# <li id="valley" style="padding: 1em;">Forecast<span>Valley</span></li>
# <!-- <li id="favs">Grooming<span>Favs</span></li> -->
# <!-- <li id="runs">Grooming<span>Report</span></li> -->
# <li id="open" style="padding: 1em;">Lift<span>History</span></li>
# <li id="lifts" style="padding: 1em;">Lift<span>Status</span></li>
# <!-- <li id="snow">Snow<span>Report</span></li> -->
# <li id="temps-history" style="padding: 1em;">Temps<span>history</span></li>
# <li id="temps" style="padding: 1em;">Temps<span>live</span></li>
# <!-- <li id="hike">Trails<span>Hiking</span></li> -->
# <!-- <li id="winds">Temps/Wind<span>Graphs</span></li> -->
# <li id="fatmap" style="padding: 1em;">Trails<span>Winter</span></li>
# <li id="video" style="padding: 1em;">Video<span>Streams</span></li>
# <!-- <li id="zones">Zones<span>Alpine</span></li> -->
# </ul>
# <ul class="sidebarMenuInner large" style="gap: 0.5em;">
# <li id="support" style="padding: 1em;">About<span>This Project</span></li>
# <li id="bike" style="padding: 1em;">Bike<span>Park</span></li>
# <!-- <li id="backcountry">Backcountry<span>Report</span></li> -->
# <li id="roads" style="padding: 1em;">Cams<span>Highway</span></li>
# <li id="cams" style="padding: 1em;">Cams<span>Mountain</span></li>
# <!-- <li id="forecast_landing_large">Forecast<span>Alpine</span></li>
#         <li id="valley">Forecast<span>Valley</span></li> -->
# <li id="weather-top" style="padding: 1em;">Forecast<span>2248m•SF</span></li>
# <li id="forecast" style="padding: 1em;">Forecast<span>1800m•RWDI</span></li>
# <li id="weather" style="padding: 1em;">Forecast<span>1400m•SF</span></li>
# <li id="valley" style="padding: 1em;">Forecast<span>Valley</span></li>
# <!-- <li id="winds">Graphs<span>Wind Temps</span></li> -->
# <!-- <li id="favs">Grooming<span>Favs</span></li> -->
# <!-- <li id="runs_history">Grooming<span>History</span></li> -->
# <!-- <li id="runs">Grooming<span>Report</span></li> -->
# <li id="open" style="padding: 1em;">Lift<span>History</span></li>
# <li id="lifts" style="padding: 1em;">Lift<span>Status</span></li>
# <!-- <li id="events">Mountain<span>Info</span></li> -->
# <!-- <li id="snow_history">Snow<span>History</span></li> -->
# <!-- <li id="snow">Snow<span>Report</span></li> -->
# <!-- <li id="ruler">Snow<span>Ruler History</span></li> -->
# <li id="temps-history" style="padding: 1em;">Temps<span>History</span></li>
# <li id="temps" style="padding: 1em;">Temps<span>Live</span></li>
# <li id="fatmap" style="padding: 1em;">Trails<span>Alpine</span></li>
# <!-- <li id="hike">Trails<span>Hiking</span></li> -->
# <!-- <li id="updates">Updates<span>#WBOPS</span></li> -->
# <li id="video_large" style="padding: 1em;">Video<span>Streams</span></li>
# <!-- <li id="zones_large">Zones<span>Alpine</span></li> -->
# </ul>
# <p class="logoTip">Tip: Click the logo for the homepage</p>
# </div>
# <script>
# $(document).ready(function() {
#     const original = window.getComputedStyle(document.documentElement).fontSize;
#     const number = parseFloat(original, 10);
#     const unit = original.replace(/(\d*.\d+)|\d+/, '');
#     const defaultFontSizeLarge = (number * 0.6) + unit;
#     const defaultFontSizeMedium = (number * 0.7) + unit;
#     const defaultFontSizeSmall = (number * 0.8) + unit;
#
#     if (number >= 22) {
#         $('body, footer').css('font-size', defaultFontSizeLarge);
#         $('h1').css('font-size', '1.2rem');
#     }
#
#     if (number > 20 && number <= 21) {
#         $('body, footer').css('font-size', defaultFontSizeLarge);
#         $('h1').css('font-size', '1.3rem');
#     }
#     if (number == 20) {
#         $('body, footer').css('font-size', defaultFontSizeMedium);
#         $('h1').css('font-size', '1.4rem');
#     }
#     if (number >= 18 && number < 20) {
#         $('body, footer').css('font-size', defaultFontSizeSmall);
#         $('h1').css('font-size', '1.5rem');
#     }
#     // $('h1').text(number);
#     // console.log(number);
#
#     function viewport() {
#         var e = window,
#             a = "inner";
#         if (!("innerWidth" in window)) {
#             a = "client";
#             e = document.documentElement || document.body;
#         }
#         return {
#             width: e[a + "Width"],
#             height: e[a + "Height"],
#         };
#     }
#
#     let deviceHeight = viewport().height;
#     let deviceWidth = viewport().width;
#
#     // $('h1').text(deviceHeight);
#     // $('h1').append(viewport().width);
#
#     if (deviceHeight <= 555) {
#         // 548 - iPhone SE, iPhone 8
#         // 553 - iPhone 6S
#         $("ul.sidebarMenuInner").css("grid-gap", "0.125em");
#         // $(".sidebarMenuInner li").css("font-size", "1.0em");
#     } else if (deviceHeight <= 630) {
#         // 617 - iPhone 8 Plus
#         // 629 - iPhone 12 Mini
#         $("ul.sidebarMenuInner").css("grid-gap", "0.33em");
#         $(".sidebarMenuInner li").css("padding", "1em");
#
#     } else if (deviceHeight <= 700) {
#         // 635 - iPhone X
#         // 649 - Galaxy 22, 22 Ultra
#         // 663 - Android basic
#         // 664 - iPhone 14
#         // 674 - OnePlus 7
#
#         $("ul.sidebarMenuInner").css("grid-gap", "0.5em");
#         $(".sidebarMenuInner li").css("padding", "1em");
#     } else if (deviceHeight == 746) {
#         // 746 - iPad
#         $("ul.sidebarMenuInner").css("grid-gap", "0.5em");
#         $(".sidebarMenuInner li").css("padding", "1em");
#
#     } else if (deviceHeight <= 760) {
#         // 702 - Galaxy 22+
#         // 713 - OnePlus 9
#         // 715 - iPhone XR
#         // 740 - iPhone 14 Pro Max
#         // 746 - iPhone 14 Plus
#         // 760 - Xiaomi
#         $("ul.sidebarMenuInner").css("grid-gap", "0.5em");
#         $(".sidebarMenuInner li").css("padding", "1.25em");
#     } else if (deviceHeight <= 777) {
#         // 775 - Pixel 7 Pro
#         $("ul.sidebarMenuInner").css("grid-gap", "0.5em");
#         $(".sidebarMenuInner li").css("padding", "1.25em");
#     } else {
#         // 783 - Poco
#         // 790 - Pixel 7
#         $("ul.sidebarMenuInner").css("grid-gap", "0.5em");
#         $(".sidebarMenuInner li").css("padding", "1.5em");
#     }
#
#     function openPage(value, site) {
#         if (site == "wp") {
#             const prefix = "https://whistlerpeak.com/" + value + "/";
#             window.open(prefix, '_self');
#         }
#         if (site == "graphs_home") {
#             const prefix = "https://whistlercharts.com/";
#             window.open(prefix, '_self');
#         }
#
#         if (site == "runs_home") {
#             const prefix = "https://whistlerruns.com/";
#             window.open(prefix, '_self');
#         }
#
#         if (site == "runs") {
#             const prefix = "https://whistlerruns.com/grooming/";
#             window.open(prefix, '_self');
#         }
#         if (site == "runs_history") {
#             const prefix = "https://whistlerruns.com/history/";
#             window.open(prefix, '_self');
#         }
#         if (site == "lifts_home") {
#             const prefix = "https://whistlerlifts.com/livelifts/";
#             window.open(prefix, '_self');
#         }
#
#         if (site == "lifts_blackcomb") {
#             const prefix = "https://whistlerlifts.com/blackcomb";
#             window.open(prefix, '_self');
#         }
#         if (site == "lifts_whistler") {
#             const prefix = "https://whistlerlifts.com/whistler";
#             window.open(prefix, '_self');
#         }
#
#         if (site == "open_runs") {
#             const prefix = "https://whistlerruns.com/epicmix/open";
#             window.open(prefix, '_self');
#         }
#
#         if (site == "lifts") {
#             const prefix = "https://whistlerlifts.com/";
#             window.open(prefix, '_self');
#         }
#         if (site == "open_home") {
#             const prefix = "https://whistleropen.com/";
#             window.open(prefix, '_self');
#         }
#         if (site == "open") {
#             const prefix = "https://whistleropen.com/" + value + "/";
#             window.open(prefix, '_self');
#         }
#
#     }
#
#
#     $("#all, #all-large").click(function() {
#         const prefix = "/all/";
#         window.open(prefix, '_self');
#     });
#
#     $("#home, #home-large").click(function() {
#         const prefix = "/";
#         window.open(prefix, '_self');
#     });
#
#     $("#weather-top, #favs, #hike, #updates, #tempslist, #bike, #fatmap, #winds, #support, #cams, #snow, #choose, #forecast, #temps, #food, #valley, #donate, #backcountry, #maps, #weather, #temps-history, #roads, #temps-history")
#         .click(function() {
#             const clickedId = $(this).attr("id");
#             const site = "wp";
#             openPage(clickedId, site);
#         });
#
#     $("#graphs, #graphs-large").click(function() {
#         const clickedId = $(this).attr("id");
#         const site = "graphs_home";
#         openPage(clickedId, site);
#     });
#     $("#runs, #runs-large").click(function() {
#         const clickedId = $(this).attr("id");
#         const site = "runs";
#         openPage(clickedId, site);
#     });
#     $("#grooming, #history-large, #grooming-large").click(function() {
#         const clickedId = $(this).attr("id");
#         const site = "runs_home";
#         openPage(clickedId, site);
#     });
#
#     $("#video, #video_large").click(function() {
#         window.open('https://whistlerpeak.com/video/', '_self');
#     });
#
#     $("#events").click(function() {
#         window.open('https://whistlerpeak.com/snow/events/', '_self');
#     });
#
#     $("#ruler").click(function() {
#         window.open('https://whistlerpeak.com/snow/ruler/', '_self');
#     });
#
#
#     $("#snowfall_history").click(function() {
#         window.open('https://whistlerpeak.com/snow/history', '_self');
#     });
#
#     $("#forecast_landing, #forecast_landing_large").click(function() {
#         window.open('https://whistlerpeak.com/choose', '_self');
#     });
#
#     $("#snow_history").click(function() {
#         window.open('https://whistlerpeak.com/snow/history', '_self');
#     });
#
#     $("#runs_history").click(function() {
#         window.open('https://whistlerruns.com/history', '_self');
#     });
#
#     $("#lifts, #lifts-large").click(function() {
#         const clickedId = $(this).attr("id");
#         const site = "lifts_home";
#         openPage(clickedId, site);
#     });
#
#     $("#lifts-blackcomb").click(function() {
#         const clickedId = $(this).attr("id");
#         const site = "lifts_blackcomb";
#         openPage(clickedId, site);
#     });
#
#     $("#open_runs, #open_runs-large").click(function() {
#         const clickedId = $(this).attr("id");
#         const site = "open_runs";
#         openPage(clickedId, site);
#     });
#
#
#     $("#lifts-whistler").click(function() {
#         const clickedId = $(this).attr("id");
#         const site = "lifts_whistler";
#         openPage(clickedId, site);
#     });
#
#     $("#open, #open-large").click(function() {
#         const clickedId = $(this).attr("id");
#         const site = "open_home";
#         openPage(clickedId, site);
#     });
#     $("#zones, #zones_large").click(function() {
#         window.open('https://whistlerlifts.com/zones/', '_self');
#     });
#
#     $("#external_zone_history").click(function() {
#         window.open('https://whistlerlifts.com/zone-history/', '_self');
#     });
#
#
#     var $checkboxes = $('input[name="navToggle"]');
#     $checkboxes.change(function() {
#         $('main section:nth-child(1), footer').toggle();
#         var checked = $(this).prop('checked');
#         if (checked) {
#             $('.spinner').css('background-color', 'var(--color-brand)');
#         } else {
#             $('.spinner').css('background-color', 'var(--color-light-secondary)');
#         }
#     })
#
#     $(".logo").click(function() {
#         document.location = "https://whistlerpeak.com/";
#     });
#
#     $(".icon-mtn").click(function() {
#         document.location = "https://whistlerpeak.com/";
#     });
#
# });
# </script> </header>
# <main>
# <section>
# <div id="notice_temps" style="display: none;">Loading...</div>
# <div id="content_temps">
# <div class="switch-container">
# <div class="slider-heading">Live Temps<br/><span>Weather Stations</span></div>
# <div class="switches">
# <span class="slider-text">sort: </span>
# <label class="switch">
# <input class="openSwitch" name="status" type="checkbox"/>
# <span class="slider openSlider"></span>
# </label>
# </div>
# </div>
# <div class="tipWrapper">
# <div class="tipFlex" id="tip_stations"><span>Click on weather stations for detailed readings:</span>
# </div></div>
# <div id="localContent"></div>
# <script>
# $(document).ready(function() {
#
#     function changeToFahrenheit() {
#         $('.metric').each(function() {
#             var celsius = parseFloat($(this).text());
#             var fahrenheit = (celsius * 9 / 5) + 32;
#             $(this).text(fahrenheit.toFixed(0) + '°F'); // Using toFixed(0)
#         });
#     }
#
#     function convertKmToMiles() {
#         $('.temp-wind').each(function() {
#             var kmh = parseFloat($(this).text());
#             var mph = kmh * 0.62137119;
#             $(this).html(mph.toFixed(0) +
#                 ' <span class="windUnits">mph</span>'); // Rounds to 2 decimal places
#         });
#     }
#
#     function changeToCelsius() {
#         $('.metric').each(function() {
#             var fahrenheit = parseFloat($(this).text());
#             var celsius = (fahrenheit - 32) * 5 / 9;
#             $(this).text(celsius.toFixed(0) + '°C'); // Using toFixed(0)
#         });
#     }
#
#     function convertMilesToKm() {
#         $('.temp-wind').each(function() {
#             var mph = parseFloat($(this).text());
#             var kmh = mph * 1.609344;
#             $(this).html(kmh.toFixed(0) +
#                 ' <span class="windUnits">km/h</span>'); // Rounds to 0 decimal places
#         });
#     }
#
#
#     function addKmh() {
#         $('.windUnits').each(function() {
#             $(this).text(' km/h');
#         });
#     }
#
#     function roundWind() {
#         $('.temp-wind').each(function() {
#             var value = parseFloat($(this).text());
#             $(this).html(value.toFixed(0) +
#                 ' <span class="windUnits">km/h</span>');
#         });
#     }
#
#     function readUnitPreference() {
#         let unitPreference = window.localStorage.getItem('unitPreference');
#         if (unitPreference === null) {
#             window.localStorage.setItem('unitPreference', 'metric');
#             roundWind();
#         }
#         if (unitPreference === 'metric') {
#             roundWind();
#         }
#         if (unitPreference === 'imperial') {
#             changeToFahrenheit();
#             convertKmToMiles();
#         }
#     }
#
#
#     function reverse() {
#         var $wrapper = $('.circle_card_container');
#         var $children = $wrapper.children().get().reverse();
#         $wrapper.empty().append($children);
#     }
#
#     function renderContent(callback) {
#         var localStorageValue = localStorage.getItem('sortTemps');
#         $.ajax({
#             type: 'POST',
#             url: 'script.php',
#             data: {
#                 localStorageValue: localStorageValue
#             },
#             success: function(response) {
#                 $('#localContent').html(response);
#                 if (typeof callback === 'function') {
#                     callback();
#                 }
#             },
#             error: function(XMLHttpRequest, textStatus, errorThrown) {
#                 $("#localContent").html("Timeout contacting server..");
#             },
#         });
#     }
#
#
#     function readStorage() {
#         var localStorageValue = localStorage.getItem('sortTemps');
#         if (localStorageValue === null) {
#             window.localStorage.setItem('sortTemps', 'card');
#             $(".openSwitch").prop('checked', true);
#         }
#         if (localStorageValue == "card") {
#             $(".openSwitch").prop('checked', true);
#         } else if (localStorageValue == "svg") {
#             $(".openSwitch").prop('checked', false);
#         }
#         renderContent(readUnitPreference);
#         checkTipStations();
#     }
#     readStorage();
#
#
#     $(".openSwitch").change(function() {
#         if ($(this).is(":checked")) {
#             window.localStorage.setItem('sortTemps', 'card');
#             reverse();
#         } else {
#             window.localStorage.setItem('sortTemps', 'svg');
#             reverse();
#
#         }
#     });
#
#
#
#     function openPage(value) {
#         let prefix = value + "/";
#         // console.log(value);
#         window.open(prefix, '_self');
#     }
#
#     $("#olympic, #base, #pigalley, #catskinner, #rhl, #rendezvous, #peak, #seventh, #harmony, #symphony, #crystal")
#         .click(function() {
#             var clickedId = $(this).attr("id");
#             window.localStorage.setItem('tipStations', 'performed');
#             openPage(clickedId);
#         });
#
#     $(document).on('click', '.card-temps', function() {
#         var clickedId = $(this).attr("id");
#         window.localStorage.setItem('tipStations', 'performed');
#         openPage(clickedId);
#     });
#
#
#     function checkTipStations() {
#         let tipStationStorage = window.localStorage.getItem('tipStations');
#         if (tipStationStorage == "performed") {
#             $('#tip_stations').hide();
#         } else {
#             $('#tip_stations').show();
#         }
#     }
#
#
#     $(document).on('click', '.toggle-units', function() {
#         let unitPreference = window.localStorage.getItem('unitPreference');
#         if (unitPreference === 'metric') {
#             window.localStorage.setItem('unitPreference', 'imperial');
#             changeToFahrenheit();
#             convertKmToMiles();
#             sendLocalStorageItemToServer('unitPreference');
#             $(this).text('Convert units to Metric');
#             $(this).removeClass('metric').addClass('imperial');
#             // $(this).css('background-color', 'var(--color-blue)');
#
#         }
#         if (unitPreference === 'imperial') {
#             window.localStorage.setItem('unitPreference', 'metric');
#             changeToCelsius();
#             convertMilesToKm();
#             sendLocalStorageItemToServer('unitPreference');
#             $(this).text('Convert units to Imperial');
#             // $(this).css('background-color', 'darkslateblue');
#         }
#     });
#
# });
# </script></div>
# </section>
# <section>
# <div id="buttons"></div>
# </section>
# </main>
# <footer>
# <div class="icon-mtn"></div>
# <div>Copyright © 2024 <a data-reveal-id="easter" href="https://whistlerpeak.com/">whistlerpeak.com</a></div>
# <div class="all-links"><a href="https://whistlerpeak.com/support/">Help support this project, contact</a></div> </footer>
# <script type="text/javascript">
#     function updateLiveTemps() {
#         $("#notice_temps").html("Loading...");
#         $.ajax({
#             type: "GET",
#             url: "block-temps-grid.php",
#             timeout: 20000,
#             success: function(data) {
#                 $("#content_temps").html(data);
#                 // $("#notice_temps").html('');
#                 const notice = document.querySelector("#notice_temps");
#                 notice.style.display = "none";
#                 window.setTimeout(() => {
#                     updateLiveTemps();
#                 }, 3600000); // 1hr setInterval
#             },
#             error: function(XMLHttpRequest, textStatus, errorThrown) {
#                 $("#notice_temps").html("Timeout contacting server..");
#                 window.setTimeout(updateLiveTemps, 100000);
#             },
#         });
#     }
#
#     function updatePlot(plot) {
#
#         $("#content_temps").hide();
#         $("#notice_temps").show();
#         $("#notice_temps").html("Loading...");
#
#         $.ajax({
#             type: "GET",
#             url: plot + ".php",
#             timeout: 20000,
#             success: function(data) {
#                 $("#content_temps").show();
#                 $("#content_temps").html(data);
#                 // $("#notice_temps").html('');
#                 const notice = document.querySelector("#notice_temps");
#                 notice.style.display = "none";
#                 $('html, body').animate({
#                     scrollTop: 0
#                 }, 0);
#                 window.setTimeout(() => {
#                     updateLiveTemps();
#                 }, 3600000); // 1hr setInterval
#             },
#             error: function(XMLHttpRequest, textStatus, errorThrown) {
#                 $("#notice_temps").html("Timeout contacting server..");
#                 window.setTimeout(updateLiveTemps, 100000);
#             },
#         });
#     }
#
#     function updateButtons() {
#         $.ajax({
#             type: "GET",
#             url: "buttons.php",
#             timeout: 20000,
#             success: function(data) {
#                 $("#buttons").html(data);
#                 window.setTimeout(updateButtons, 3600000);
#             },
#             error: function(XMLHttpRequest, textStatus, errorThrown) {
#                 $("#buttons").html("Timeout contacting server..");
#                 window.setTimeout(updateButtons, 100000);
#             },
#         });
#     }
#
#     $(document).ready(function() {
#         updateLiveTemps(); // Live Temps
#     });
#     </script>
# </body></html>

# %%
soup.findAll('content_temps')
# Out:
# []

# %%
#still isn't scraping the Javascript data correctly. Will have to return to this...

# %% [markdown]
# Now explore from https://spotwx.com

# %%
url = 'https://spotwx.com/products/grib_index.php?model=rdps_10km&lat=50.11226&lon=-122.94773&tz=America/Vancouver&label=Blackcomb,%20Whistler,%20British%20Columbia'


res = requests.get(url)

# %%
#use Beautiful Soup to convert this into a soup
soup = bs4.BeautifulSoup(res.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head><!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-R1BMZX9H0H"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-R1BMZX9H0H');
# </script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>SpotWx | Forecast</title><link href="../media/css/graph_page.css" media="screen, print, projection" rel="stylesheet"/></head>
# <body> <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>SpotWx - Forecast</title>
# <script crossorigin="anonymous" integrity="sha256-/xUj+3OJU5yExlq6GSYGSHk7tPXikynS7ogEvDej/m4=" src="https://code.jquery.com/jquery-3.6.0.min.js"></script>
# <script src="../js/html2canvas.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# $(function () {
#  var zType = 'none'
#   Highcharts.setOptions({
#     chart: {
#       plotBackgroundImage: '../images/paper.jpg',
#       zoomType: zType,
#       borderWidth: 1,
#       borderColor: '#AAAAAA',
#       borderRadius: 0,
#       marginBottom: 60,
#       marginRight: 75,
#       marginTop: 50,
#       plotShadow: true,
#       plotBorderWidth: 1
#     },
#     credits: {
#       text: 'SpotWx',
#       href: 'https://spotwx.com'
#     },
#     exporting: {
#       enabled: true,
#       sourceWidth: 1200,
#       type: 'image/jpeg',
#       width: 1200,
#       fallbackToExportServer: false
#     },
#     title: {
#       style: {
#         color: '#000',
#         font: 'bold 16px "Trebuchet MS", Verdana, sans-serif'
#       }
#     },
#     subtitle: {
#       style: {
#         color: '#666666',
#         font: '10px "Trebuchet MS", Verdana, sans-serif'
#       }
#        },
#     xAxis: [{
#       tickPixelInterval: 55,
#       gridLineWidth: 0.5,
#       minorGridLineWidth: 0.3,
#      linewidth: 1,
#       lineColor: '#000',
#       type: 'datetime',
#       tickColor: '#000',
#       labels: {
#         format: '{value:%l%P}',
#         style: {
#           color: '#000',
#           font: '11px Trebuchet MS, Verdana, sans-serif'
#         }
#       },
#       title: {
#         style: {
#           color: '#333',
#           fontWeight: 'bold',
#           fontSize: '12px',
#           fontFamily: 'Trebuchet MS, Verdana, sans-serif'
#         }
#       }
#     },{
#       linkedTo: 0,
#       type: 'datetime',
#       tickInterval: 24 * 3600 * 1000,
#       labels: {
#         format: '{value:<span style="font-size: 12px; font-weight: bold">%a</span> %b %e}',
#         align: 'left',
#         rotation: 0,
#         x: 3,
#         y: 8
#       },
#       opposite: true,
#       tickLength: 20,
#       gridLineWidth: 1.3
#     }],
#     yAxis: {
#        //minorTickInterval: 'auto',
#        allowDecimals: false,
#        lineColor: '#000',
#        lineWidth: 1,
#        tickWidth: 1,
#        tickColor: '#000',
#        labels: {
#          style: {
#            color: '#000',
#            font: '11px Trebuchet MS, Verdana, sans-serif'
#          }
#        },
#        title: {
#          style: {
#            color: '#333',
#            fontWeight: 'bold',
#            fontSize: '12px',
#            fontFamily: 'Trebuchet MS, Verdana, sans-serif'
#          }
#        }
#     },
#     legend: {
#        borderRadius: 0,
#        borderWidth: 1,
#        backgroundColor: '#FFFFFF',
#        y: 5,       padding: 5,       itemStyle: {
#          font: '9pt Trebuchet MS, Verdana, sans-serif',
#          color: 'black'
#        },
#        itemHoverStyle: {
#          color: '#039'
#        },
#        itemHiddenStyle: {
#          color: 'gray'
#        }
#     },
#     labels: {
#        style: {
#          color: '#99b'
#        }
#      },
#      tooltip: {
#        xDateFormat: '%l:%M %p, %a, %b %e, %Y',
#        backgroundColor: 'rgba(255,255,255,0.70)',
#        crosshairs: true,
#        font: '10px "Trebuchet MS", Verdana, sans-serif',
#       borderWidth: 1,
#        borderColor: '#AAA',
#        shared: true
#      }
# });
# Highcharts.getSVG = function(charts) {
#   var svgArr = [],
#     top = 0,
#     width = 0,
#     endWidth = 0;
#   Highcharts.each(charts, function(chart) {
#     var svg = chart.getSVG(),
#       // Get width/height of SVG for export
#       svgWidth = +svg.match(
#         /^<svg[^>]*width\s*=\s*\"?(\d+)\"?[^>]*>/
#       )[1],
#       svgHeight = +svg.match(
#         /^<svg[^>]*height\s*=\s*\"?(\d+)\"?[^>]*>/
#       )[1];
#     svg = svg.replace(
#       '<svg',
#       '<g transform="translate(' + width + ', ' + top + ')" '
#     );
#     svg = svg.replace('</svg>', '</g>');
#     width += svgWidth;
#     endWidth = Math.max(endWidth, width)
#     if (width === 2 * svgWidth) {
#       width = 0;
#       top += svgHeight;
#     }
#     svgArr.push(svg);
#   });
#   top += 400;
#   return '<svg height="' + top + '" width="' + endWidth +
#     '" version="1.1" xmlns="http://www.w3.org/2000/svg">' +
#     svgArr.join('') + '</svg>';
# };
# Highcharts.exportCharts = function(charts, options) {
#   options = Highcharts.merge(Highcharts.getOptions().exporting, options);
#   console.log(options);
#   Highcharts.post(options.url, {
#     filename: options.filename || 'chart',
#     type: options.type,
#     width: options.width,
#     svg: Highcharts.getSVG(charts)
#   });
# };
#
# var chart_title;
# var chart_temperature;
# var chart_precip;
# var chart_wind;
# var chart_lftx;
# var chart_cape;
# var chart_llwind;
# var chart_pbl;
# var chart_solar;
# var chart_hainesx;
# $(document).ready(function() {
#    chart_title = new Highcharts.Chart({
#      chart: {
#       plotBackgroundImage: '',
#          renderTo: 'container_title'
#      },
#      title: {
#        text: 'RDPS forecast for Blackcomb, Whistler, British Columbia @ Lat:50.11226, Lon:-122.94773'
#      },
#      subtitle: {
#                 text: 'Model date: <b> 5:00 pm, Tue Oct 15, 2024 </b> (PDT, UTC-7 hrs), Model elevation: <b>1448m / 4751ft</b>, Land Proportion: <b>98%',
#                 x: -10
#      }
#    });
#    chart_temperature = new Highcharts.Chart({
#      chart: {
#          renderTo: 'container_temperature',
#          alignTicks: false
#      },
#      title: {
#        text: 'Temperature and Relative Humidity'
#      },
#      plotOptions: {
#        series: {
#          marker: {
#            fillColor: '#FFFFFF',
#            lineWidth: 1,
#            lineColor: null,
#            radius: 3
#          }
#        }
#      },
#      tooltip: {
#        useHTML: true,
#        headerFormat: '<small><b>{point.key}</b></small><table>',
#        pointFormat: '<tr><td><span style="color: {series.color}">\u25CF</span>{series.name}: </td>' +
#        '<td style="white-space:nowrap"><b>{point.y}</b></td></tr>',
#        footerFormat: '</table>'
#      },
#        yAxis: [{  //primary axis
#        //minorTickInterval: 'auto',
#         labels: {
#           format: '{value}°'
#         },
#         height: '55%',
#         offset: 0,
#        lineColor: '#FF0000',
#        lineWidth: 2,
#         startOnTick: true,
#        endOnTick: true,
#        tickPixelInterval: 25,
#         units: '°C',
#              title: {
#                text: 'Temperature (°C)',
#             style: {
#             color: '#FF0000'
#           }
#              },
#         plotLines: [{
#                value: 0,
#                width: 2,
#                color: '#808080'
#              }]
#              //min: -50
#            },{  //secondary
#              plotLines: [{
#                value: 100,
#                width: 2,
#                color: '#808080'
#              }],
#              top: '60%',             height: '40%',             offset: 0,             lineColor: '#0000FF',
#         lineWidth: 2,
#              endOnTick: true,
#              tickPixelInterval: 40,
#              title: {               text: 'RH',               style: {                 color: '#0000FF'               }             },             labels: {
#                format: '{value}%'
#              },
#              min: 0,             max: 100,             units: '%',             startOnTick: true,             endOnTick: true,             tickInterval: 20,             opposite: false           },{  //duplicate right temperature axis
#              opposite: true,
#              labels: {
#                format: '{value}°'
#              },
#              height: '55%',
#              offset: 0,
#              lineColor: '#FF0000',
#              lineWidth: 2,
#              startOnTick: true,
#              endOnTick: true,
#              tickPixelInterval: 25,
#              units: '°C',
#              title: {
#                text: 'Temperature (°C)',
#                style: {
#                  color: '#FF0000'
#                }
#              },
#              linkedTo: 0
#            },{  //duplicate right RH axis
#              opposite: true,
#              linkedTo: 1,
#              top: '60%',             height: '40%',             offset: 0,             lineColor: '#0000FF',
#              lineWidth: 2,
#              endOnTick: true,
#              tickPixelInterval: 40,
#              title: {               text: 'RH',               style: {                 color: '#0000FF'               }             },             labels: {
#                format: '{value}%'
#              },
#              min: 0,             max: 100,             units: '%',             startOnTick: true,             endOnTick: true,             tickInterval: 20           }],
#             series: [{
#               name: 'Temp.',
#               type: 'spline',
#               data: [
# [Date.UTC(2024, 9, 15, 17, 00), 5.8],[Date.UTC(2024, 9, 15, 18, 00), 4.7],[Date.UTC(2024, 9, 15, 19, 00), 2.9],[Date.UTC(2024, 9, 15, 20, 00), 2.6],[Date.UTC(2024, 9, 15, 21, 00), 2.2],[Date.UTC(2024, 9, 15, 22, 00), 1.9],[Date.UTC(2024, 9, 15, 23, 00), 2.1],[Date.UTC(2024, 9, 16, 00, 00), 2.8],[Date.UTC(2024, 9, 16, 01, 00), 2.7],[Date.UTC(2024, 9, 16, 02, 00), 2.3],[Date.UTC(2024, 9, 16, 03, 00), 2.1],[Date.UTC(2024, 9, 16, 04, 00), 1.8],[Date.UTC(2024, 9, 16, 05, 00), 1.5],[Date.UTC(2024, 9, 16, 06, 00), 1.1],[Date.UTC(2024, 9, 16, 07, 00), 1.1],[Date.UTC(2024, 9, 16, 08, 00), 1.2],[Date.UTC(2024, 9, 16, 09, 00), 0.9],[Date.UTC(2024, 9, 16, 10, 00), 1.2],[Date.UTC(2024, 9, 16, 11, 00), 1.7],[Date.UTC(2024, 9, 16, 12, 00), 1.6],[Date.UTC(2024, 9, 16, 13, 00), 1.4],[Date.UTC(2024, 9, 16, 14, 00), 1.4],[Date.UTC(2024, 9, 16, 15, 00), 1.4],[Date.UTC(2024, 9, 16, 16, 00), 0.9],[Date.UTC(2024, 9, 16, 17, 00), 0.5],[Date.UTC(2024, 9, 16, 18, 00), -
76],[Date.UTC(2024, 9, 18, 16, 00), 78],[Date.UTC(2024, 9, 18, 17, 00), 79],[Date.UTC(2024, 9, 18, 18, 00), 83],[Date.UTC(2024, 9, 18, 19, 00), 87],[Date.UTC(2024, 9, 18, 20, 00), 92],[Date.UTC(2024, 9, 18, 21, 00), 93],[Date.UTC(2024, 9, 18, 22, 00), 94],[Date.UTC(2024, 9, 18, 23, 00), 92],[Date.UTC(2024, 9, 19, 00, 00), 94],[Date.UTC(2024, 9, 19, 01, 00), 94],[Date.UTC(2024, 9, 19, 02, 00), 95],[Date.UTC(2024, 9, 19, 03, 00), 94],[Date.UTC(2024, 9, 19, 04, 00), 94],[Date.UTC(2024, 9, 19, 05, 00), 94],
#               ],
#               zIndex: 1,
#               legendIndex: 5,
#               lineWidth: 2,
#               shadow: {width: 5, opacity: 0.10},
#               tooltip: {
#                 valueSuffix: '%'
#               },
#               fillColor: {
#                 linearGradient: [0, 0, 0, 100],
#                 stops: [
#                   [0, 'rgba(50, 55, 250,0.1)'],
#                   [1, 'rgba(50,55,255,0.00)']
#                 ]
#               }
#            }]
#         });
#    chart_precip = new Highcharts.Chart({
#      chart: {
#          renderTo: 'container_precip',
#          alignTicks: false
#      },
#      title: {
#        text: 'Precipitation and Clouds'
#      },
#      subtitle: {
#         text: 'Rain, freezing rain, and ice pellets are measured in mm. Snow is in cm.<br>Snow is assumed to have a 10:1 snow to liquid ratio.',
#         align: 'left',
#         y: 0,
#         x: 0
#      },
#      plotOptions: {
#         column: {
#           pointPlacement: 'null'
#         },
#        series: {
#          marker: {
#            enabled: false
#          }
#        }
#      },
#      tooltip: {
#        useHTML: true,
#        headerFormat: '<small><b>{point.key}</b></small><table>',
#        pointFormat: '<tr><td><span style="color: {series.color}">\u25CF</span>{series.name}: </td>' +
#        '<td style="white-space:nowrap"><b>{point.y}</b></td></tr>',
#        footerFormat: '</table>'
#      },
#      yAxis: [{  //primary axis
#        height: '65%',
#        minRange: 5,
#        lineColor: '#0000FF',
#        lineWidth: 2,
#        endOnTick: true,
#        tickPixelInterval: 20,
#        title: {
#          text: 'Precip (mm/cm)',
#          style: {
#            color: '#0000FF'
#          }
#        },
#        min: 0,
#        units: 'mm/cm',
#        startOnTick: true,
#        endOnTick: true,
#        opposite: false
#       },{  //secondary
#        height: '65%',
#        offset: 38,
#        title: {
#          text: 'THK',
#          align: 'high',
#          offset: 0,
#          rotation: 0,
#          y: -8,
#          x: 0,
#          style: {
#            color: '#BF00BF'
#          }
#        },
#        min: 490,
#        max: 590,
#        lineColor: '#BB00BB',
#        lineWidth: 2,
#        startOnTick: false,
#        endOnTick: false,
#        gridLineWidth: 0,
#        tickPositions: [500,520,540,550,560,580,600],
#        opposite: true
#       },{  //third
#         top: '73%',        height: '27%',        offset: 0,        lineColor: '#888',
#         lineWidth: 2,
#         endOnTick: true,
#         tickPixelInterval: 40,
#         title: {          text: 'Clouds %',          style: {            color: '#555'          }        },        min: 0,        max: 100,        units: '%',        startOnTick: true,        endOnTick: true,        tickInterval: 50,        opposite: false      },{  //right precip axis
#        height: '65%',
#        minRange: 10,
#        offset: 0,
#        linkedTo: 0,
#        lineColor: '#0000FF',
#        lineWidth: 2,
#        endOnTick: false,
#        tickPixelInterval: 20,
#        title: {
#          text: 'PCP',
#          align: 'high',
#          offset: 0,
#          rotation: 0,
#          y: -8,
#          x: 0,
#          style: {
#            color: '#0000FF'
#          }
#        },
#        min: 0,
#        startOnTick: true,
#        endOnTick: true,
#        opposite: true
#      }],
#             series: [{
#               name: 'Ttl Rain',
#               type: 'areaspline',
#               data: [
# [Date.UTC(2024, 9, 15, 17, 00), 0.0],[Date.UTC(2024, 9, 15, 18, 00), 0.0],[Date.UTC(2024, 9, 15, 19, 00), 0.0],[Date.UTC(2024, 9, 15, 20, 00), 0.0],[Date.UTC(2024, 9, 15, 21, 00), 0.0],[Date.UTC(2024, 9, 15, 22, 00), 0.0],[Date.UTC(2024, 9, 15, 23, 00), 0.0],[Date.UTC(2024, 9, 16, 00, 00), 0.1],[Date.UTC(2024, 9, 16, 01, 00), 0.5],[Date.UTC(2024, 9, 16, 02, 00), 1.6],[Date.UTC(2024, 9, 16, 03, 00), 2.6],[Date.UTC(2024, 9, 16, 04, 00), 2.9],[Date.UTC(2024, 9, 16, 05, 00), 3.0],[Date.UTC(2024, 9, 16, 06, 00), 3.1],[Date.UTC(2024, 9, 16, 07, 00), 3.2],[Date.UTC(2024, 9, 16, 08, 00), 3.2],[Date.UTC(2024, 9, 16, 09, 00), 3.3],[Date.UTC(2024, 9, 16, 10, 00), 3.3],[Date.UTC(2024, 9, 16, 11, 00), 3.3],[Date.UTC(2024, 9, 16, 12, 00), 3.4],[Date.UTC(2024, 9, 16, 13, 00), 3.5],[Date.UTC(2024, 9, 16, 14, 00), 3.5],[Date.UTC(2024, 9, 16, 15, 00), 3.6],[Date.UTC(2024, 9, 16, 16, 00), 3.7],[Date.UTC(2024, 9, 16, 17, 00), 3.7],[Date.UTC(2024, 9, 16, 18, 00), 3.7],[Date.UTC(2024, 9, 16, 19, 00), 3.7],[Date.UTC(2024, 9, 16, 20, 00), 3.7],[Date.UTC(2024, 9, 16, 21, 00), 3.7],[Date.UTC(2024, 9, 16, 22, 00), 3.7],[Date.UTC(2024, 9, 16, 23, 00), 3.7],[Date.UTC(2024, 9, 17, 00, 00), 3.7],[Date.UTC(2024, 9, 17, 01, 00), 3.7],[Date.UTC(2024, 9, 17, 02, 00), 3.7],[Date.UTC(2024, 9, 17, 03, 00), 3.7],[Date.UTC(2024, 9, 17, 04, 00), 3.7],[Date.UTC(2024, 9, 17, 05, 00), 3.7],[Date.UTC(2024, 9, 17, 06, 00), 3.7],[Date.UTC(2024, 9, 17, 07, 00), 3.7],[Date.UTC(2024, 9, 17, 08, 00), 3.7],[Date.UTC(2024, 9, 17, 09, 00), 3.7],[Date.UTC(2024, 9, 17, 10, 00), 3.7],[Date.UTC(2024, 9, 17, 11, 00), 3.7],[Date.UTC(2024, 9, 17, 12, 00), 3.7],[Date.UTC(2024, 9, 17, 13, 00), 3.7],[Date.UTC(2024, 9, 17, 14, 00), 3.7],[Date.UTC(2024, 9, 17, 15, 00), 3.7],[Date.UTC(2024, 9, 17, 16, 00), 3.7],[Date.UTC(2024, 9, 17, 17, 00), 3.7],[Date.UTC(2024, 9, 17, 18, 00), 3.7],[Date.UTC(2024, 9, 17, 19, 00), 3.8],[Date.UTC(2024, 9, 17, 20, 00), 3.8],[Date.UTC(2024, 9, 17, 21, 00), 4.0],[Date.UTC(2024, 9, 17, 22, 00), 4.1],[Date.UTC(2024, 9, 17, 23, 00), 4.2],[Date.UTC(2024, 9, 18, 00, 00), 4.2],[Date.UTC(2024, 9, 18, 01, 00), 4.2],[Date.UTC(2024, 9, 18, 02, 00), 4.2],[Date.UTC(2024, 9, 18, 03, 00), 4.2],[Date.UTC(2024, 9, 18, 04, 00), 4.2],[Date.UTC(2024, 9, 18, 05, 00), 4.2],[Date.UTC(2024, 9, 18, 06, 00), 4.2],[Date.UTC(2024, 9, 18, 07, 00), 4.2],[Date.UTC(2024, 9, 18, 08, 00), 4.2],[Date.UTC(2024, 9, 18, 09, 00), 4.2],[Date.UTC(2024, 9, 18, 10, 00), 4.2],[Date.UTC(2024, 9, 18, 11, 00), 4.3],[Date.UTC(2024, 9, 18, 12, 00), 4.3],[Date.UTC(2024, 9, 18, 13, 00), 4.4],[Date.UTC(2024, 9, 18, 14, 00), 4.4],[Date.UTC(2024, 9, 18, 15, 00), 4.5],[Date.UTC(2024, 9, 18, 16, 00), 4.5],[Date.UTC(2024, 9, 18, 17, 00), 4.7],[Date.UTC(2024, 9, 18, 18, 00), 4.9],[Date.UTC(2024, 9, 18, 19, 00), 5.4],[Date.UTC(2024, 9, 18, 20, 00), 6.4],[Date.UTC(2024, 9, 18, 21, 00), 7.3],[Date.UTC(2024, 9, 18, 22, 00), 8.1],[Date.UTC(2024, 9, 18, 23, 00), 9.1],[Date.UTC(2024, 9, 19, 00, 00), 10.5],[Date.UTC(2024, 9, 19, 01, 00), 11.7],[Date.UTC(2024, 9, 19, 02, 00), 13.6],[Date.UTC(2024, 9, 19, 03, 00), 15.2],[Date.UTC(2024, 9, 19, 04, 00), 16.2],[Date.UTC(2024, 9, 19, 05, 00), 17.2],
#               ],
#               index: 3,
#               legendIndex: 2,
#               lineWidth: 2,
#               shadow: {width: 5, opacity: 0.10},
#               tooltip: {
#                 valueSuffix: ' mm'
#               },
#               color: 'rgba(55,123,250,1.0)',
#               fillColor: 'rgba(122,198,245,0.1)',
#               linecolor: 'rgba(55,123,250,1)'
#            }, {
#               name: 'Ttl Snow',
#               type: 'areaspline',
#               data: [
# ...
#               ],
#               index: 2,
#               legendIndex: 2,
#               lineWidth: 2,
#               shadow: {width: 5, opacity: 0.10},
#               tooltip: {
#                 pointFormat: '<tr><td><span style="color: {series.color}">\u25CF</span>{series.name}: </td>' +
#                 '<td style="white-space:nowrap"><b>{point.y} ({point.desc})</b></td></tr>'
#               },
#               marker: {
#                 enabled: true
#               },
#               color: 'rgba(245,86,16,1.0)'
#            }, {
#               name: 'Haines Index - High Elev',
#               type: 'spline',
#               data: [
# {x: Date.UTC(2024, 9, 15, 17, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 15, 18, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 15, 19, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 15, 20, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 15, 21, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 15, 22, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 15, 23, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 00, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 01, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 02, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 03, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 04, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 05, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 06, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 07, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 08, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 09, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 10, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 11, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 12, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 13, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 14, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 15, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 16, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 17, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 18, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 19, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 20, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 21, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 22, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 23, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 00, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 01, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 02, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 03, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 04, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 05, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 06, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 07, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 08, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 09, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 10, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 11, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 12, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 13, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 14, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 15, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 16, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 17, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 18, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 19, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 20, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 21, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 22, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 23, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 00, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 01, 00), y: 4, desc: 'Low'},{x: Date.UTC(2024, 9, 18, 02, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 03, 00), y: 3, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 04, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 05, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 06, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 07, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 08, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 09, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 10, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 11, 00), y: 2, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 12, 00), y: 2, desc: 'Very ...
#               ],
#               index: 3,
#               visible: false,
#               legendIndex: 3,
#               lineWidth: 2,
#               shadow: {width: 5, opacity: 0.10},
#               tooltip: {
#                 pointFormat: '<tr><td><span style="color: {series.color}">\u25CF</span>{series.name}: </td>' +
#                 '<td style="white-space:nowrap"><b>{point.y} ({point.desc})</b></td></tr>'
#               },
#               marker: {
#                 enabled: true
#               },
#               color: 'rgba(240,43,200,1.0)'
#            }, {
#               name: 'C-Haines Index - Mid Elev',
#               type: 'spline',
#               data: [
# {x: Date.UTC(2024, 9, 15, 17, 00), y: 4.3, desc: 'Low'},{x: Date.UTC(2024, 9, 15, 18, 00), y: 4.5, desc: 'Low'},{x: Date.UTC(2024, 9, 15, 19, 00), y: 3.6, desc: 'Low'},{x: Date.UTC(2024, 9, 15, 20, 00), y: 2.6, desc: 'Very low'},{x: Date.UTC(2024, 9, 15, 21, 00), y: 2.0, desc: 'Very low'},{x: Date.UTC(2024, 9, 15, 22, 00), y: 1.6, desc: 'Very low'},{x: Date.UTC(2024, 9, 15, 23, 00), y: 1.6, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 00, 00), y: 1.7, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 01, 00), y: 1.8, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 02, 00), y: 1.5, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 03, 00), y: 1.6, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 04, 00), y: 2.0, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 05, 00), y: 2.5, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 06, 00), y: 2.1, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 07, 00), y: 2.2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 08, 00), y: 2.7, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 09, 00), y: 3.2, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 10, 00), y: 3.7, desc: 'Low'},{x: Date.UTC(2024, 9, 16, 11, 00), y: 4.3, desc: 'Low'},{x: Date.UTC(2024, 9, 16, 12, 00), y: 4.5, desc: 'Low'},{x: Date.UTC(2024, 9, 16, 13, 00), y: 4.5, desc: 'Low'},{x: Date.UTC(2024, 9, 16, 14, 00), y: 4.9, desc: 'Moderate'},{x: Date.UTC(2024, 9, 16, 15, 00), y: 4.7, desc: 'Moderate'},{x: Date.UTC(2024, 9, 16, 16, 00), y: 4.5, desc: 'Low'},{x: Date.UTC(2024, 9, 16, 17, 00), y: 4.6, desc: 'Moderate'},{x: Date.UTC(2024, 9, 16, 18, 00), y: 4.3, desc: 'Low'},{x: Date.UTC(2024, 9, 16, 19, 00), y: 3.6, desc: 'Low'},{x: Date.UTC(2024, 9, 16, 20, 00), y: 2.8, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 21, 00), y: 2.4, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 22, 00), y: 2.0, desc: 'Very low'},{x: Date.UTC(2024, 9, 16, 23, 00), y: 2.3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 00, 00), y: 2.4, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 01, 00), y: 2.6, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 02, 00), y: 2.8, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 03, 00), y: 2.8, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 04, 00), y: 2.6, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 05, 00), y: 2.3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 06, 00), y: 1.8, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 07, 00), y: 1.6, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 08, 00), y: 1.7, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 09, 00), y: 2.0, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 10, 00), y: 2.6, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 11, 00), y: 3.3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 12, 00), y: 3.8, desc: 'Low'},{x: Date.UTC(2024, 9, 17, 13, 00), y: 3.9, desc: 'Low'},{x: Date.UTC(2024, 9, 17, 14, 00), y: 4.2, desc: 'Low'},{x: Date.UTC(2024, 9, 17, 15, 00), y: 4.1, desc: 'Low'},{x: Date.UTC(2024, 9, 17, 16, 00), y: 3.8, desc: 'Low'},{x: Date.UTC(2024, 9, 17, 17, 00), y: 3.3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 18, 00), y: 2.8, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 19, 00), y: 2.2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 20, 00), y: 1.7, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 21, 00), y: 1.3, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 22, 00), y: 1.2, desc: 'Very low'},{x: Date.UTC(2024, 9, 17, 23, 00), y: 1.0, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 00, 00), y: 0.9, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 01, 00), y: 0.9, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 02, 00), y: 0.7, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 03, 00), y: 0.7, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 04, 00), y: 1.2, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 05, 00), y: 1.8, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 06, 00), y: 1.8, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 07, 00), y: 1.8, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 08, 00), y: 1.4, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 09, 00), y: 1.7, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 10, 00), y: 2.1, desc: 'Very low'},{x: Date.UTC(2024, 9, 18, 11, 00), y: 2.4, desc:  ...
#               ],
#               index: 4,
#               legendIndex: 4,
#               lineWidth: 2,
#               shadow: {width: 5, opacity: 0.10},
#               tooltip: {
#                 pointFormat: '<tr><td><span style="color: {series.color}">\u25CF</span>{series.name}: </td>' +
#                 '<td style="white-space:nowrap"><b>{point.y} ({point.desc})</b></td></tr>'
#               },
#               marker: {
#                 enabled: true
#               },
#               color: 'rgba(145,71,17,1.0)',
#               linecolor: 'rgba(145,71,17,1)'
#            }]
#         });
# });
# $('#export-png').click(function() {
#     Highcharts.exportCharts([
#   chart_title,  chart_temperature,  chart_precip,  chart_wind,  chart_lftx,  chart_cape,  chart_llwind,  chart_pbl,  chart_solar,  chart_hainesx]);
# });
# });
# </script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/highcharts/11.2.0/highcharts.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/highcharts/11.2.0/highcharts-more.min.js"></script>
# <script src="https://code.highcharts.com/modules/exporting.js"></script>
# <script src="https://code.highcharts.com/modules/offline-exporting.js"></script>
# <script src="https://code.highcharts.com/modules/heatmap.js"></script>
# <div id="tocanvas">
# <div style="min-width: 400px; max-width: 1200px; margin-left: auto; margin-right: auto; text-align:center;"><a href="https://www.buymeacoffee.com/SpotWx" target="_blank"><img alt="Buy Me A Coffee" src="https://cdn.buymeacoffee.com/buttons/v2/default-yellow.png" style="height: 35px !important;width: 130px !important;"/></a> <a href="https://www.patreon.com/SpotWx" target="_blank"><img alt="Become a Patron" src="../img/patreon_button1.webp" style="height: 35px !important;width: 130px !important;"/></a> <a href="https://www.paypal.com/donate/?hosted_button_id=53G8VBMRD5BLE" target="_blank"><img alt="Donate with PayPal" src="../img/paypal_donate.webp" style="height: 35px !important;width: 130px !important;"/></a></div><div style="min-width: 400px; max-width: 1200px; margin: 0 auto"><div style="float:left;width:80px;"><a href="../."><img border="0" src="../images/SpotWx_icon_tiny.png"/></a></div><a href="./grib_index.php?model=rdps_10km&amp;lat=50.11226&amp;lon=-122.94773&amp;tz=America/Vancouver&amp;display=table"><img border="0" src="../media/images/table.gif"/>Open Tabular version</a><div style="float:right;width:auto;"><a href="../setunits.html">Change Units</a></div></div><br/>
# <div id="container_title" style="min-width: 400px; max-width: 1200px; height: 60px; margin: 0 auto; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.25);border: 1px solid #CCC"></div>
# <div id="container_temperature" style="min-width: 400px; max-width: 1200px; height: 330px; margin: 0 auto; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.25);border: 1px solid #CCC"></div>
# <div id="container_precip" style="min-width: 400px; max-width: 1200px; height: 310px; margin: 0 auto; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.25);border: 1px solid #CCC"></div>
# <div id="container_wind" style="min-width: 400px; max-width: 1200px; height: 230px; margin: 0 auto; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.25);border: 1px solid #CCC"></div>
# <div id="container_lftx" style="min-width: 400px; max-width: 1200px; height: 230px; margin: 0 auto; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.25);border: 1px solid #CCC"></div>
# <div id="container_cape" style="min-width: 400px; max-width: 1200px; height: 230px; margin: 0 auto; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.25);border: 1px solid #CCC"></div>
# <div id="container_llwind" style="min-width: 400px; max-width: 1200px; height: 230px; margin: 0 auto; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.25);border: 1px solid #CCC"></div>
# <div id="container_pbl" style="min-width: 400px; max-width: 1200px; height: 230px; margin: 0 auto; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.25);border: 1px solid #CCC"></div>
# <div id="container_solar" style="min-width: 400px; max-width: 1200px; height: 230px; margin: 0 auto; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.25);border: 1px solid #CCC"></div>
# <div id="container_hainesx" style="min-width: 400px; max-width: 1200px; height: 230px; margin: 0 auto; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.25);border: 1px solid #CCC"></div>
# <div style="min-width: 400px; max-width: 1200px; margin: 0 auto"><a href="https://spotwx.com/en/termsofuse.html">Terms of Use</a><br/><i>All data are provided "AS IS" by Environment and Climate Change Canada. SpotWx is not responsible for the quality, accuracy, or completeness of the data or any derived products. The data are provided without warranty or condition of any nature, including but not limited to implied warranties of merchantability and fitness for a particular purpose. In no event shall SpotWx be liable for any damages whatsoever in respect of any claim, action, demand or proceeding of any kind arising from or related to your use, inability to use or performance of the data.</i></div>
# </div>
# <!--<script src="../js/jquery.min.js"></script>-->
# <!--<script src="../js/bootstrap.min.js"></script>-->
# </body>
# </html>

# %%
print(soup.find(class_='highcharts-root'))
# Out:
# None
